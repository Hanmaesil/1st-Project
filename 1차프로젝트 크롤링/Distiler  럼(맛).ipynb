# %%
from selenium import webdriver as wb
from selenium.webdriver.common.keys import Keys
import time
import random
import requests as req
from bs4 import BeautifulSoup as bs
import re
import pandas as pd

# %%
pattern = re.compile('url\((.*?)\)') 
name_list = [] #이름
score_list = [] #별점
abv_list = [] #도수
des_list = [] #설명
tnote_list = [] #테이스팅 노트
taste_list = [] #맛, 향
img_list = [] # 이미지
num_list = [] #순서
num = 0

driver = wb.Chrome()
driver.maximize_window()
time.sleep(random.uniform(2,4))

for j in range(1,13):
    driver.get('https://distiller.com/search?page='+str(j)+'&sort=total_num_of_ratings&spirit_style_id=62')
    time.sleep(random.uniform(2,4))
    for i in range(10) :
        try:
            btn = driver.find_elements_by_class_name("name")
            btn[i].click()
            time.sleep(random.uniform(2,4))
            name = driver.find_element_by_css_selector("span.secondary-headline.name")
            name_list.append(name.text)
            try:
                score = driver.find_element_by_css_selector('#main-content > div > div.spirit-show.center-column.js-carousel.sugarcane-content > div.primary-content > div.tabs > div > div > div.stats-container > div > div > div > div > div.rating-display__value.average-rating > span')
                score_list.append(score.text)
            except:
                score_list.append("none")
            abv = driver.find_element_by_css_selector('#main-content > div > div.spirit-show.center-column.js-carousel.sugarcane-content > div.primary-content > div.tabs > div > div > div.spirit-show__description-container > div.other-details-container > ul > div > li.detail.abv > div.value')
            abv_list.append(abv.text)
            try:
                des = driver.find_element_by_css_selector('#main-content > div > div.spirit-show.center-column.js-carousel.sugarcane-content > div.primary-content > div.tabs > div > div > div.spirit-show__description-container > div.only-big > p')
                des_list.append(des.text)
                print("설명 입력")
            except:
                des_list.append("none")
                print("설명없음")
            try:
                tnote = driver.find_element_by_css_selector('#main-content > div > div.spirit-show.center-column.js-carousel.sugarcane-content > div.primary-content > div.tabs > div > div > div.details-module.spirit-show__tasting-notes.screened > div.content > p')
                tnote_list.append(tnote.text)
            except:
                tnote_list.append("none") 
            try :
                canvasTemp=driver.find_element_by_css_selector(".js-flavor-profile-chart")
                taste_list.append(canvasTemp.get_attribute('data-flavors'))
            except :
                taste_list.append("none")
                print("오류")
            url = driver.current_url
            res = req.get(url)
            found = re.search(pattern,res.text)
            img_list.append(found.group(1))
            num_list.append(num+1)
            num = num + 1
            driver.back()
            time.sleep(random.uniform(2,4))
        except:
            body = driver.find_element_by_css_selector("body")
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)#
            body.send_keys(Keys.ARROW_DOWN)
            print("다운")
        
    
dic = {"순서" : num_list,"상품명" : name_list, "별점" : score_list, "도수" : abv_list, "설명" : des_list, "테이스트노트" : tnote_list, "맛과향" : taste_list, "이미지" : img_list}
fin = pd.DataFrame(dic)
fin
# Out:
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_5500/3063837345.py:21: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   btn = driver.find_elements_by_class_name("name")
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_5500/3063837345.py:24: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   name = driver.find_element_by_css_selector("span.secondary-headline.name")
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_5500/3063837345.py:27: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   score = driver.find_element_by_css_selector('#main-content > div > div.spirit-show.center-column.js-carousel.sugarcane-content > div.primary-content > div.tabs > div > div > div.stats-container > div > div > div > div > div.rating-display__value.average-rating > span')
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_5500/3063837345.py:31: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   abv = driver.find_element_by_css_selector('#main-content > div > div.spirit-show.center-column.js-carousel.sugarcane-content > div.primary-content > div.tabs > div > div > div.spirit-show__description-container > div.other-details-container > ul > div > li.detail.abv > div.value')
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_5500/3063837345.py:34: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   des = driver.find_element_by_css_selector('#main-content > div > div.spirit-show.center-column.js-carousel.sugarcane-content > div.primary-content > div.tabs > div > div > div.spirit-show__description-container > div.only-big > p')
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_5500/3063837345.py:41: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   tnote = driver.find_element_by_css_selector('#main-content > div > div.spirit-show.center-column.js-carousel.sugarcane-content > div.primary-content > div.tabs > div > div > div.details-module.spirit-show__tasting-notes.screened > div.content > p')
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_5500/3063837345.py:46: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   canvasTemp=driver.find_element_by_css_selector(".js-flavor-profile-chart")
# 설명 입력
# 설명 입력
# 설명 입력
# 설명 입력
# 오류
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_5500/3063837345.py:60: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   body = driver.find_element_by_css_selector("body")
# 다운
# 설명 입력
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 설명없음
# 오류
# 설명 입력
# 설명 입력
# 설명 입력
# 오류
# 다운
# 설명 입력
# 설명없음
# 오류
# 설명 입력
# 설명없음
# 오류
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 설명없음
# 오류
# 설명 입력
# 다운
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명 입력
# 설명 입력
# 설명 입력
# 오류
# 설명없음
# 오류
# 설명 입력
# 오류
# 설명 입력
# 오류
# 다운
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 설명없음
# 오류
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 오류
# 설명없음
# 오류
# 다운
# 설명 입력
# 오류
# 설명 입력
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 오류
# 다운
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명 입력
# 다운
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 설명없음
# 오류
# 설명 입력
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 다운
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명 입력
# 오류
# 설명없음
# 오류
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 오류
# 다운
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 다운
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 다운
# 설명 입력
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 설명없음
# 오류
# 설명없음
# 오류
# 다운
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
#       순서                                       상품명    별점    도수  \
# 0      1  PLANTATION PINEAPPLE STIGGINS' FANCY RUM  4.12  40.0
# 1      2                              PYRAT XO RUM  3.53  40.0
# 2      3                       MALIBU ORIGINAL RUM   2.8  21.0
# 3      4                 LEGENDARIO ELIXIR DE CUBA  3.68  34.0
# 4      5                SIESTA KEY TOASTED COCONUT   4.4  35.0
# ..   ...                                       ...   ...   ...
# 103  104                   DANCING PINES SPICE RUM   3.0  40.0
# 104  105     RUM OF THE WORLD 3 YO CARIBBEAN BLEND   3.5  42.0
# 105  106    CALICO’S CREW THE CANNONEERS EXPLOSIVE  3.25  48.0
# 106  107              OLDMAN SPIRITS RUM PROJECT 2  0.25  40.0
# 107  108                   FLENSBURGER SENIOR 1965   4.5  42.0
#
#                                                     설명  \
# 0    Named for a character in Charles Dickens’ “The...
# 1    Pyrat was originally conceived in 1997 by the ...
# 2    Malibu Original coconut flavored rum was desig...
# 3    Elixir de Cuba is the flagship spirit in the R...
# 4    Siesta Key Toasted Coconut Rum is produced in ...
# ..                                                 ...
# 103                                               none
# 104                                               none
# 105                                               none
# 106                                               none
# 107                                               none
#
#                                                 테이스트노트  \
# 0    "The pineapple is upfront on the nose, but not...
# 1    "This is a very sweet and tangy style of rum. ...
# 2    "This product somehow manages to taste entirel...
# 3                                                 none
# 4    "The aroma of the rum is that of freshly-cut c...
# ..                                                 ...
# 103                                               none
# 104                                               none
# 105                                               none
# 106                                               none
# 107                                               none
#
#                                                    맛과향  \
# 0    {"smoky":35,"earthy":10,"spicy":60,"herbal":10...
# 1    {"smoky":0,"earthy":10,"spicy":20,"herbal":0,"...
# 2    {"smoky":0,"earthy":0,"spicy":0,"herbal":0,"oi...
# 3                                                 none
# 4    {"smoky":40,"earthy":25,"spicy":60,"herbal":20...
# ..                                                 ...
# 103                                               none
# 104                                               none
# 105                                               none
# 106                                               none
# 107                                               none
#
#                                                    이미지
# 0    https://ip-distiller.imgix.net/images/spirits/...
# 1    https://ip-distiller.imgix.net/images/spirits/...
# 2    https://ip-distiller.imgix.net/images/spirits/...
# 3    https://ip-distiller.imgix.net/images/spirits/...
# 4    https://ip-distiller.imgix.net/images/spirits/...
# ..                                                 ...
# 103  https://ip-distiller.imgix.net/images/spirits/...
# 104  https://ip-distiller.imgix.net/images/spirits/...
# 105  https://ip-distiller.imgix.net/images/spirits/...
# 106  https://ip-distiller.imgix.net/images/spirits/...
# 107  https://ip-distiller.imgix.net/images/spirits/...
#
# [108 rows x 8 columns]

# %%
fin.to_csv("distiller 럼 - 맛.csv", encoding="utf-8-sig")

# %%
driver = wb.Chrome()
driver.maximize_window()
driver.get('https://distiller.com/spirits/plantation-pineapple-stiggins-fancy-rum')

# %%
name = driver.find_element_by_css_selector("span.secondary-headline.name")
name.text
# Out:
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_10628/1311794012.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   name = driver.find_element_by_css_selector("span.secondary-headline.name")
# "PLANTATION PINEAPPLE STIGGINS' FANCY RUM"

# %%
score = driver.find_element_by_css_selector('#main-content > div > div.spirit-show.center-column.js-carousel.sugarcane-content > div.primary-content > div.tabs > div > div > div.stats-container > div > div > div > div > div.rating-display__value.average-rating > span')
score.text
# Out:
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_10628/241906501.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   score = driver.find_element_by_css_selector('#main-content > div > div.spirit-show.center-column.js-carousel.sugarcane-content > div.primary-content > div.tabs > div > div > div.stats-container > div > div > div > div > div.rating-display__value.average-rating > span')
# '4.12'

# %%
abv = driver.find_element_by_css_selector('#main-content > div > div.spirit-show.center-column.js-carousel.sugarcane-content > div.primary-content > div.tabs > div > div > div.spirit-show__description-container > div.other-details-container > ul > div > li.detail.abv > div.value')
abv.text
# Out:
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_10628/2499925922.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   abv = driver.find_element_by_css_selector('#main-content > div > div.spirit-show.center-column.js-carousel.sugarcane-content > div.primary-content > div.tabs > div > div > div.spirit-show__description-container > div.other-details-container > ul > div > li.detail.abv > div.value')
# '40.0'

# %%
des = driver.find_element_by_css_selector('#main-content > div > div.spirit-show.center-column.js-carousel.sugarcane-content > div.primary-content > div.tabs > div > div > div.spirit-show__description-container > div.only-big > p')
des.text
# Out:
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_10628/2977553083.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   des = driver.find_element_by_css_selector('#main-content > div > div.spirit-show.center-column.js-carousel.sugarcane-content > div.primary-content > div.tabs > div > div > div.spirit-show__description-container > div.only-big > p')
# 'Named for a character in Charles Dickens’ “The Pickwick Papers,” the Pineapple Stiggins’ Fancy Rum began as a one-off collaboration between Alexandre Gabriel and cocktail historian David Wondrich. The demand was strong enough that Plantation made it a proper release. Pineapple rinds are infused with their Plantation 3 Stars Rum for one week, then pot distilled. The fruit is separately steeped in Plantation Original Dark Rum for three months. The two liquids are blended and the resulting Pineapple Rum is rested in casks for three months before bottling.'
