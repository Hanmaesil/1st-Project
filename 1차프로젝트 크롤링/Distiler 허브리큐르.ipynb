# %%
from selenium import webdriver as wb
from selenium.webdriver.common.keys import Keys
import time
import random
import requests as req
from bs4 import BeautifulSoup as bs
import re
import pandas as pd

# %%
pattern = re.compile('url\((.*?)\)') 
name_list = [] #이름
score_list = [] #별점
abv_list = [] #도수
des_list = [] #설명
tnote_list = [] #테이스팅 노트
taste_list = [] #맛, 향
img_list = [] # 이미지
num_list = [] #순서
num = 0

driver = wb.Chrome()
driver.maximize_window()
time.sleep(random.uniform(2,4))

for j in range(1,13):
    driver.get('https://distiller.com/search?page='+str(j)+'&sort=total_num_of_ratings&spirit_style_id=134')
    time.sleep(random.uniform(2,4))
    for i in range(10) :
        try:
            btn = driver.find_elements_by_class_name("name")
            btn[i].click()
            time.sleep(random.uniform(2,4))
            name = driver.find_element_by_css_selector("span.secondary-headline.name")
            name_list.append(name.text)
            try:
                score = driver.find_element_by_css_selector('#main-content > div > div.spirit-show.center-column.js-carousel.liqueur-content > div.primary-content > div > div > div > div.stats-container > div > div > div > div > div.rating-display__value.average-rating > span')
                score_list.append(score.text)
            except:
                score_list.append("none")
            abv = driver.find_element_by_css_selector('#main-content > div > div.spirit-show.center-column.js-carousel.liqueur-content > div.primary-content > div > div > div > div.spirit-show__description-container > div.other-details-container > ul > div > li.detail.abv > div.value')
            abv_list.append(abv.text)
            try:
                des = driver.find_element_by_css_selector('#main-content > div > div.spirit-show.center-column.js-carousel.liqueur-content > div.primary-content > div > div > div > div.spirit-show__description-container > div.only-big > p')
                des_list.append(des.text)
                print("설명 입력")
            except:
                des_list.append("none")
                print("설명없음")
            try:
                tnote = driver.find_element_by_css_selector('#main-content > div > div.spirit-show.center-column.js-carousel.liqueur-content > div.primary-content > div.tabs > div > div > div.details-module.spirit-show__tasting-notes.screened > div.content > p')
                tnote_list.append(tnote.text)
            except:
                tnote_list.append("none")
            try :
                canvasTemp=driver.find_element_by_css_selector(".js-flavor-profile-chart")
                taste_list.append(canvasTemp.get_attribute('data-flavors'))
            except :
                taste_list.append("none")
                print("오류")
            url = driver.current_url
            res = req.get(url)
            found = re.search(pattern,res.text)
            img_list.append(found.group(1))
            num_list.append(num+1)
            num = num + 1
            driver.back()
            time.sleep(random.uniform(2,4))
        except:
            body = driver.find_element_by_css_selector("body")
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)#
            body.send_keys(Keys.ARROW_DOWN)
            print("다운")
        
    
dic = {"순서" : num_list,"상품명" : name_list, "별점" : score_list, "도수" : abv_list, "설명" : des_list, "테이스트노트" : tnote_list, "맛과향" : taste_list, "이미지" : img_list}
fin = pd.DataFrame(dic)
fin
# Out:
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_7124/2978025923.py:21: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   btn = driver.find_elements_by_class_name("name")
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_7124/2978025923.py:24: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   name = driver.find_element_by_css_selector("span.secondary-headline.name")
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_7124/2978025923.py:27: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   score = driver.find_element_by_css_selector('#main-content > div > div.spirit-show.center-column.js-carousel.liqueur-content > div.primary-content > div > div > div > div.stats-container > div > div > div > div > div.rating-display__value.average-rating > span')
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_7124/2978025923.py:31: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   abv = driver.find_element_by_css_selector('#main-content > div > div.spirit-show.center-column.js-carousel.liqueur-content > div.primary-content > div > div > div > div.spirit-show__description-container > div.other-details-container > ul > div > li.detail.abv > div.value')
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_7124/2978025923.py:34: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   des = driver.find_element_by_css_selector('#main-content > div > div.spirit-show.center-column.js-carousel.liqueur-content > div.primary-content > div > div > div > div.spirit-show__description-container > div.only-big > p')
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_7124/2978025923.py:41: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   tnote = driver.find_element_by_css_selector('#main-content > div > div.spirit-show.center-column.js-carousel.liqueur-content > div.primary-content > div.tabs > div > div > div.details-module.spirit-show__tasting-notes.screened > div.content > p')
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_7124/2978025923.py:46: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   canvasTemp=driver.find_element_by_css_selector(".js-flavor-profile-chart")
# 설명 입력
# 설명 입력
# 설명 입력
# 설명 입력
# 오류
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_7124/2978025923.py:60: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   body = driver.find_element_by_css_selector("body")
# 다운
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명없음
# 오류
# 설명 입력
# 오류
# 설명 입력
# 설명없음
# 오류
# 설명 입력
# 설명 입력
# 오류
# 다운
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명없음
# 오류
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 설명없음
# 오류
# 설명 입력
# 오류
# 다운
# 설명없음
# 오류
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 설명없음
# 오류
# 설명없음
# 오류
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명없음
# 오류
# 다운
# 설명없음
# 오류
# 설명 입력
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 다운
# 설명없음
# 오류
# 설명없음
# 오류
# 설명 입력
# 설명없음
# 오류
# 설명 입력
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 다운
# 설명 입력
# 오류
# 설명없음
# 오류
# 설명 입력
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 다운
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 다운
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명 입력
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 다운
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 다운
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 다운
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명 입력
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 다운
# 설명없음
# 오류
# 설명없음
# 오류
# 설명 입력
# 설명없음
# 오류
# 설명없음
# 오류
#       순서                                 상품명    별점    도수  \
# 0      1        JACK DANIEL'S TENNESSEE FIRE  2.85  35.0
# 1      2           SOUTHERN COMFORT ORIGINAL  2.54  35.0
# 2      3                            DRAMBUIE  3.87  40.0
# 3      4                    JIM BEAM VANILLA  2.55  35.0
# 4      5                            LICOR 43   4.0  31.0
# ..   ...                                 ...   ...   ...
# 103  104             GALLIANO BLACK SAMBUCCA   3.0  30.0
# 104  105                   POLI MIELE GRAPPA   4.0  35.0
# 105  106  REILLY'S ROCK & RYE GINGER WHISKEY   4.0  33.0
# 106  107           PARAMOUNT CRÈME DE MENTHE  none  25.0
# 107  108       PRADĚD ALTVATER BYLINNÝ LIKÉR  none  38.0
#
#                                                     설명  \
# 0    Jack Daniel's Tennessee Fire was released coun...
# 1    Southern Comfort was first created by M.W. Her...
# 2    An essential ingredient in a handful of classi...
# 3    Released in summer 2017, Jim Beam Vanilla is m...
# 4    Inspired by the ancient Roman recipe for Liqvo...
# ..                                                 ...
# 103                                               none
# 104                                               none
# 105  Ginger was considered a powerful curative in t...
# 106                                               none
# 107                                               none
#
#                                                 테이스트노트  \
# 0    "Cloying sweet nose with obvious cinnamon and ...
# 1    "Look for an amber hue and an aggressively sac...
# 2    "Look for a pale yellow color, and a light ora...
# 3                                                 none
# 4    "Yellow-golden in hue, this liqueur has a shar...
# ..                                                 ...
# 103                                               none
# 104                                               none
# 105  "The sharp spiciness of the ginger mingles wit...
# 106                                               none
# 107                                               none
#
#                                                    맛과향  \
# 0    {"sweet":95,"rich":60,"spicy":50,"herbal":0,"f...
# 1    {"sweet":100,"rich":30,"spicy":15,"herbal":0,"...
# 2    {"sweet":85,"rich":80,"spicy":25,"herbal":85,"...
# 3                                                 none
# 4    {"sweet":90,"rich":90,"spicy":40,"herbal":30,"...
# ..                                                 ...
# 103                                               none
# 104                                               none
# 105  {"sweet":75,"rich":60,"spicy":50,"herbal":0,"f...
# 106                                               none
# 107                                               none
#
#                                                    이미지
# 0    https://ip-distiller.imgix.net/images/spirits/...
# 1    https://ip-distiller.imgix.net/images/spirits/...
# 2    https://ip-distiller.imgix.net/images/spirits/...
# 3    https://ip-distiller.imgix.net/images/spirits/...
# 4    https://ip-distiller.imgix.net/images/spirits/...
# ..                                                 ...
# 103  https://ip-distiller.imgix.net/images/spirits/...
# 104  https://ip-distiller.imgix.net/images/spirits/...
# 105  https://ip-distiller.imgix.net/images/spirits/...
# 106  https://ip-distiller.imgix.net/images/spirits/...
# 107  https://ip-distiller.imgix.net/images/spirits/...
#
# [108 rows x 8 columns]

# %%
fin.to_csv("distiller-허브리큐르.csv", encoding="utf-8-sig")
