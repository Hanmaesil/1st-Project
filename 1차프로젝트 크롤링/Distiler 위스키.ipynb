# %%
from selenium import webdriver as wb
from selenium.webdriver.common.keys import Keys
import time
import random
import requests as req
from bs4 import BeautifulSoup as bs
import re
import pandas as pd

# %%
pattern = re.compile('url\((.*?)\)') 
name_list = [] #이름
wtype_list= [] #타입
score_list = [] #별점
abv_list = [] #도수
des_list = [] #설명
tnote_list = [] #테이스팅 노트
taste_list = [] #맛, 향
img_list = [] # 이미지
num_list = [] #순서
num = 0

driver = wb.Chrome()
driver.maximize_window()
time.sleep(random.uniform(2,4))

for j in range(26,51):
    driver.get('https://distiller.com/search?page='+str(j)+'&sort=total_num_of_ratings')
    time.sleep(random.uniform(2,4))
    for i in range(10) :
        try:
            btn = driver.find_elements_by_class_name("name")
            btn[i].click()
            time.sleep(random.uniform(2,4))
            name = driver.find_element_by_css_selector("span.secondary-headline.name")
            name_list.append(name.text)
            try:
                wtype = driver.find_element_by_css_selector('#main-content > div > div.spirit-show.center-column.js-carousel.whiskey-content > div.top-image > div.vitals > div > h2.ultra-mini-headline.type')
                wtype_list.append(wtype.text)
            except:
                wtype_list.append("none")
            try:
                score = driver.find_element_by_css_selector('#main-content > div > div.spirit-show.center-column.js-carousel.whiskey-content > div.primary-content > div.tabs > div > div > div.stats-container > div > div > div > div > div.rating-display__value.average-rating > span')
                score_list.append(score.text)
            except:
                score_list.append("none")
            try:
                abv = driver.find_element_by_css_selector('#main-content > div > div.spirit-show.center-column.js-carousel.whiskey-content > div.primary-content > div.tabs > div > div > div.spirit-show__description-container > div.other-details-container > ul > div > li.detail.abv > div.value')
                abv_list.append(abv.text)
            except:
                abv_list.append("none")
            try:
                des = driver.find_element_by_css_selector('#main-content > div > div.spirit-show.center-column.js-carousel.whiskey-content > div.primary-content > div.tabs > div > div > div.spirit-show__description-container > div.only-big > p')
                des_list.append(des.text)
                print("설명 입력")
            except:
                des_list.append("none")
                print("설명없음")
            try:
                tnote = driver.find_element_by_css_selector('#main-content > div > div.spirit-show.center-column.js-carousel.whiskey-content > div.primary-content > div.tabs > div > div > div.details-module.spirit-show__tasting-notes.screened > div.content > p')
                tnote_list.append(tnote.text)
            except:
                tnote_list.append("none")
            try :
                canvasTemp=driver.find_element_by_css_selector(".js-flavor-profile-chart")
                taste_list.append(canvasTemp.get_attribute('data-flavors'))
            except :
                taste_list.append("none")
                print("오류")
            url = driver.current_url
            res = req.get(url)
            found = re.search(pattern,res.text)
            img_list.append(found.group(1))
            num_list.append(num+1)
            num = num + 1
            driver.back()
            time.sleep(random.uniform(2,4))
        except:
            body = driver.find_element_by_css_selector("body")
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)#
            body.send_keys(Keys.ARROW_DOWN)
            print("다운")
        
    
dic = {"순서" : num_list,"상품명" : name_list, "타입" : wtype_list, "별점" : score_list, "도수" : abv_list, "설명" : des_list, "테이스트노트" : tnote_list, "맛과향" : taste_list, "이미지" : img_list}
fin = pd.DataFrame(dic)
fin
# Out:
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_1392/1972275314.py:22: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   btn = driver.find_elements_by_class_name("name")
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_1392/1972275314.py:25: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   name = driver.find_element_by_css_selector("span.secondary-headline.name")
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_1392/1972275314.py:28: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   wtype = driver.find_element_by_css_selector('#main-content > div > div.spirit-show.center-column.js-carousel.whiskey-content > div.top-image > div.vitals > div > h2.ultra-mini-headline.type')
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_1392/1972275314.py:33: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ...

# %%
fin.to_csv("distiller 위스키(2).csv", encoding="utf-8-sig")

# %%
'https://distiller.com/search?page='+str(j)+'&sort=total_num_of_ratings'

# %%
driver = wb.Chrome()
driver.maximize_window()
driver.get('https://distiller.com/spirits/lagavulin-16')

# %%
tnote = driver.find_element_by_css_selector('#main-content > div > div.spirit-show.center-column.js-carousel.whiskey-content > div.primary-content > div.tabs > div > div > div.details-module.spirit-show__tasting-notes.screened > div.content > p')
tnote.text
# Out:
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_14788/3030063358.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   tnote = driver.find_element_by_css_selector('#main-content > div > div.spirit-show.center-column.js-carousel.whiskey-content > div.primary-content > div.tabs > div > div > div.details-module.spirit-show__tasting-notes.screened > div.content > p')
# '"Vegetarians need not be alarmed. Despite the meaty, brisket-y aroma to this whisky, cows were not harmed in its production. Peat smoke is integrated throughout the dram and that lavish mouthful of whisky that you are experiencing leads to the discovery of seaweed, fruit, and tobacco. Hedonists, this one\'s for you."'

# %%
name_list = [] #이름
wtype_list= [] #타입
score_list = [] #별점
abv_list = [] #도수
des_list = [] #설명
tnote_list = [] #테이스팅 노트
taste_list = [] #맛, 향
img_list = [] # 이미지
num_list = [] #순서

# %%
abv_list
# Out:
# ['60.5', '48.6']

# %%
'main-content > div > div.spirit-show.center-column.js-carousel.sugarcane-content > div.primary-content > div > div > div > div.spirit-show__description-container > div.other-details-container > ul > div > li.detail.abv > div.value
'main-content > div > div.spirit-show.center-column.js-carousel.whiskey-content > div.primary-content > div.tabs > div > div > div.spirit-show__description-container > div.other-details-container > ul > div > li.detail.abv > div.value'

# %%
body = driver.find_element_by_css_selector("body")
body.send_keys(Keys.PAGE_DOWN)
# Out:
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_14788/314149229.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   body = driver.find_element_by_css_selector("body")

# %%
pattern = re.compile('url\((.*?)\)') 
name_list = [] #이름
wtype_list= [] #타입
score_list = [] #별점
abv_list = [] #도수
des_list = [] #설명
tnote_list = [] #테이스팅 노트
taste_list = [] #맛, 향
img_list = [] # 이미지
num_list = [] #순서
num = 0
for i in range(10) :
        try:
            btn = driver.find_elements_by_class_name("name")
            btn[i].click()
            time.sleep(random.uniform(2,4))
            name = driver.find_element_by_css_selector("span.secondary-headline.name")
            name_list.append(name.text)
            try:
                wtype = driver.find_element_by_css_selector('#main-content > div > div.spirit-show.center-column.js-carousel.whiskey-content > div.top-image > div.vitals > div > h2.ultra-mini-headline.type')
                wtype_list.append(wtype.text)
            except:
                wtype_list.append("none")
            try:
                score = driver.find_element_by_css_selector('#main-content > div > div.spirit-show.center-column.js-carousel.whiskey-content > div.primary-content > div.tabs > div > div > div.stats-container > div > div > div > div > div.rating-display__value.average-rating > span')
                score_list.append(score.text)
            except:
                score_list.append("none")
            abv = driver.find_element_by_css_selector('#main-content > div > div.spirit-show.center-column.js-carousel.whiskey-content > div.primary-content > div.tabs > div > div > div.spirit-show__description-container > div.other-details-container > ul > div > li.detail.abv > div.value')
            abv_list.append(abv.text)
            try:
                des = driver.find_element_by_css_selector('#main-content > div > div.spirit-show.center-column.js-carousel.whiskey-content > div.primary-content > div.tabs > div > div > div.spirit-show__description-container > div.only-big > p')
                des_list.append(des.text)
                print("설명 입력")
            except:
                des_list.append("none")
                print("설명없음")
            try:
                tnote = driver.find_element_by_css_selector('#main-content > div > div.spirit-show.center-column.js-carousel.whiskey-content > div.primary-content > div.tabs > div > div > div.details-module.spirit-show__tasting-notes.screened > div.content > p')
                tnote_list.append(tnote.text)
            except:
                tnote_list.append("none")
            try :
                canvasTemp=driver.find_element_by_css_selector(".js-flavor-profile-chart")
                taste_list.append(canvasTemp.get_attribute('data-flavors'))
            except :
                taste_list.append("none")
                print("오류")
            url = driver.current_url
            res = req.get(url)
            found = re.search(pattern,res.text)
            img_list.append(found.group(1))
            num_list.append(num+1)
            num = num + 1
            driver.back()
            time.sleep(random.uniform(2,4))
        except:
            body = driver.find_element_by_css_selector("body")
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)#
            body.send_keys(Keys.ARROW_DOWN)
            print("다운")
        
    
dic = {"순서" : num_list,"상품명" : name_list, "타입" : wtype_list, "별점" : score_list, "도수" : abv_list, "설명" : des_list, "테이스트노트" : tnote_list, "맛과향" : taste_list, "이미지" : img_list}
fin = pd.DataFrame(dic)
fin
# Out:
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_14788/3574534109.py:14: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   btn = driver.find_elements_by_class_name("name")
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_14788/3574534109.py:17: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   name = driver.find_element_by_css_selector("span.secondary-headline.name")
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_14788/3574534109.py:20: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   wtype = driver.find_element_by_css_selector('#main-content > div > div.spirit-show.center-column.js-carousel.whiskey-content > div.top-image > div.vitals > div > h2.ultra-mini-headline.type')
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_14788/3574534109.py:25: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
# ...

# %%
name_list = [] #이름
wtype_list= [] #타입
score_list = [] #별점
abv_list = [] #도수
des_list = [] #설명
tnote_list = [] #테이스팅 노트
taste_list = [] #맛, 향
img_list = [] # 이미지
num_list = [] #순서

# %%
img_list
# Out:
# ['https://ip-distiller.imgix.net/images/spirits/0a37cf50-64f4-0133-cc35-5ef75d7f8a37/obegley_dubh_reserve_tile.jpg?w=280&amp;h=280&amp;mark-w=70&amp;mark-h=70&amp;fit=crop&amp;crop=right&amp;mark-align=top,left&amp;mark-pad=0&amp;mark=',
#  'https://ip-distiller.imgix.net/images/spirits/026c2d90-64dc-0133-4300-4286c7b0de56/new_world_projects_port_double_cask_1_single_malt_tile.jpg?w=280&amp;h=280&amp;mark-w=70&amp;mark-h=70&amp;fit=crop&amp;crop=right&amp;mark-align=top,left&amp;mark-pad=0&amp;mark=']
