# %%
from selenium import webdriver as wb
from selenium.webdriver.common.keys import Keys
import time
import random
import requests as req
from bs4 import BeautifulSoup as bs
import re
import pandas as pd

# %%
pattern = re.compile('url\((.*?)\)') 
name_list = [] #이름
score_list = [] #별점
abv_list = [] #도수
des_list = [] #설명
tnote_list = [] #테이스팅 노트
taste_list = [] #맛, 향
img_list = [] # 이미지
num_list = [] #순서
num = 0

driver = wb.Chrome()
driver.maximize_window()
time.sleep(random.uniform(2,4))

for j in range(1,11):
    driver.get('https://distiller.com/search?page='+str(j)+'&sort=total_num_of_ratings&spirit_style_id=140')
    time.sleep(random.uniform(2,4))
    for i in range(10) :
        try:
            btn = driver.find_elements_by_class_name("name")
            btn[i].click()
            time.sleep(random.uniform(2,4))
            name = driver.find_element_by_css_selector("span.secondary-headline.name")
            name_list.append(name.text)
            try:
                score = driver.find_element_by_css_selector('#main-content > div > div.spirit-show.center-column.js-carousel.liqueur-content > div.primary-content > div > div > div > div.stats-container > div > div > div > div > div.rating-display__value.average-rating > span')
                score_list.append(score.text)
            except:
                score_list.append("none")
            abv = driver.find_element_by_css_selector('#main-content > div > div.spirit-show.center-column.js-carousel.liqueur-content > div.primary-content > div > div > div > div.spirit-show__description-container > div.other-details-container > ul > div > li.detail.abv > div.value')
            abv_list.append(abv.text)
            try:
                des = driver.find_element_by_css_selector('#main-content > div > div.spirit-show.center-column.js-carousel.liqueur-content > div.primary-content > div > div > div > div.spirit-show__description-container > div.only-big > p')
                des_list.append(des.text)
                print("설명 입력")
            except:
                des_list.append("none")
                print("설명없음")
            try:
                tnote = driver.find_element_by_css_selector('#main-content > div > div.spirit-show.center-column.js-carousel.liqueur-content > div.primary-content > div.tabs > div > div > div.details-module.spirit-show__tasting-notes.screened > div.content > p')
                tnote_list.append(tnote.text)
            except:
                tnote_list.append("none")
            try :
                canvasTemp=driver.find_element_by_css_selector(".js-flavor-profile-chart")
                taste_list.append(canvasTemp.get_attribute('data-flavors'))
            except :
                taste_list.append("none")
                print("오류")
            url = driver.current_url
            res = req.get(url)
            found = re.search(pattern,res.text)
            img_list.append(found.group(1))
            num_list.append(num+1)
            num = num + 1
            driver.back()
            time.sleep(random.uniform(2,4))
        except:
            body = driver.find_element_by_css_selector("body")
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)#
            body.send_keys(Keys.ARROW_DOWN)
            print("다운")
        
    
dic = {"순서" : num_list,"상품명" : name_list, "별점" : score_list, "도수" : abv_list, "설명" : des_list, "테이스트노트" : tnote_list, "맛과향" : taste_list, "이미지" : img_list}
fin = pd.DataFrame(dic)
fin
# Out:
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_8820/3377953070.py:21: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   btn = driver.find_elements_by_class_name("name")
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_8820/3377953070.py:24: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   name = driver.find_element_by_css_selector("span.secondary-headline.name")
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_8820/3377953070.py:27: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   score = driver.find_element_by_css_selector('#main-content > div > div.spirit-show.center-column.js-carousel.liqueur-content > div.primary-content > div > div > div > div.stats-container > div > div > div > div > div.rating-display__value.average-rating > span')
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_8820/3377953070.py:31: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   abv = driver.find_element_by_css_selector('#main-content > div > div.spirit-show.center-column.js-carousel.liqueur-content > div.primary-content > div > div > div > div.spirit-show__description-container > div.other-details-container > ul > div > li.detail.abv > div.value')
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_8820/3377953070.py:34: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   des = driver.find_element_by_css_selector('#main-content > div > div.spirit-show.center-column.js-carousel.liqueur-content > div.primary-content > div > div > div > div.spirit-show__description-container > div.only-big > p')
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_8820/3377953070.py:41: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   tnote = driver.find_element_by_css_selector('#main-content > div > div.spirit-show.center-column.js-carousel.liqueur-content > div.primary-content > div.tabs > div > div > div.details-module.spirit-show__tasting-notes.screened > div.content > p')
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_8820/3377953070.py:46: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   canvasTemp=driver.find_element_by_css_selector(".js-flavor-profile-chart")
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 설명없음
# 오류
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_8820/3377953070.py:60: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   body = driver.find_element_by_css_selector("body")
# 다운
# 설명없음
# 오류
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명없음
# 오류
# 설명 입력
# 설명없음
# 오류
# 설명 입력
# 오류
# 다운
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명 입력
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 다운
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명 입력
# 오류
# 설명없음
# 오류
# 설명 입력
# 설명없음
# 오류
# 다운
# 설명 입력
# 설명없음
# 오류
# 설명없음
# 오류
# 설명 입력
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 다운
# 설명없음
# 오류
# 설명 입력
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명 입력
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 다운
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명 입력
# 오류
# 설명없음
# 오류
# 다운
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명 입력
# 설명없음
# 오류
# 설명없음
# 오류
# 다운
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명 입력
# 오류
# 다운
# 설명없음
# 오류
# 설명없음
# 오류
# 설명 입력
# 설명없음
# 오류
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 설명없음
# 오류
# 설명 입력
# 오류
# 다운
# 설명 입력
# 설명 입력
# 다운
# 다운
# 다운
#     순서                                   상품명    별점    도수  \
# 0    1                          JÄGERMEISTER  3.56  35.0
# 1    2                               CAMPARI  3.89  24.0
# 2    3                                APEROL  3.52  11.0
# 3    4                      JEPPSON’S MALORT  2.27  70.0
# 4    5                                UNICUM  3.92  40.0
# ..  ..                                   ...   ...   ...
# 82  83           DON CICCIO & FIGLI AMBROSIA  none  15.0
# 83  84                           BIANCOSARTI  none  28.0
# 84  85                        GRANADA-VALLET  none  32.0
# 85  86            BLUE LION CHICORÉE LIQUEUR  none  40.0
# 86  87  DON CICCIO & FIGLI CERASUM APERITIVO  none  23.0
#
#                                                    설명  \
# 0   Jägermeister was created by Curt Mast in 1934 ...
# 1   Campari was created circa 1860 by a Lombardy-b...
# 2   Aperol first debuted a century ago, in 1919. K...
# 3                                                none
# 4                                                none
# ..                                                ...
# 82  Don Ciccio & Figli Ambrosia is an aperitivo cr...
# 83                                               none
# 84  Granada-Vallet is a bitter pomegranate liqueur...
# 85  Made by New Hampshire’s Tamworth Distilling, t...
# 86  Cerasum is based on a traditional Italian reci...
#
#                                                테이스트노트  \
# 0                                                none
# 1   "Campari has bright orange red color and the n...
# 2   "A delicate and fruity nose kicks off with str...
# 3                                                none
# 4                                                none
# ..                                                ...
# 82  "Ambrosia is beautiful and distinctive in the ...
# 83                                               none
# 84                                               none
# 85  "This liqueur has a color reminiscent of root ...
# 86  "Mashed dark cherries and a slight herbal arom...
#
#                                                   맛과향  \
# 0                                                none
# 1   {"sweet":55,"rich":50,"spicy":35,"herbal":35,"...
# 2   {"sweet":60,"rich":40,"spicy":0,"herbal":30,"f...
# 3                                                none
# 4                                                none
# ..                                                ...
# 82  {"sweet":50,"rich":40,"spicy":10,"herbal":30,"...
# 83                                               none
# 84                                               none
# 85  {"sweet":60,"rich":70,"spicy":0,"herbal":0,"fr...
# 86  {"sweet":20,"rich":20,"spicy":20,"herbal":50,"...
#
#                                                   이미지
# 0   https://ip-distiller.imgix.net/images/spirits/...
# 1   https://ip-distiller.imgix.net/images/spirits/...
# 2   https://ip-distiller.imgix.net/images/spirits/...
# 3   https://ip-distiller.imgix.net/images/spirits/...
# 4   https://ip-distiller.imgix.net/images/spirits/...
# ..                                                ...
# 82  https://ip-distiller.imgix.net/images/spirits/...
# 83  https://ip-distiller.imgix.net/images/spirits/...
# 84  https://ip-distiller.imgix.net/images/spirits/...
# 85  https://ip-distiller.imgix.net/images/spirits/...
# 86  https://ip-distiller.imgix.net/images/spirits/...
#
# [87 rows x 8 columns]

# %%
fin.to_csv("distiller-비터(쓴)리큐르.csv", encoding="utf-8-sig")
