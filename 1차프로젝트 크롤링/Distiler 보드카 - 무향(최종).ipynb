# %%
from selenium import webdriver as wb
from selenium.webdriver.common.keys import Keys
import time
import random
import requests as req
from bs4 import BeautifulSoup as bs
import re
import pandas as pd

# %%
pattern = re.compile('url\((.*?)\)') 
name_list = [] #이름
score_list = [] #별점
abv_list = [] #도수
des_list = [] #설명
taste_list = [] #맛, 향
img_list = [] # 이미지
num_list = [] #순서
num = 0

driver = wb.Chrome()
driver.maximize_window()
time.sleep(random.uniform(2,4))

for j in range(1,30):
    driver.get('https://distiller.com/search?page='+str(j)+'&sort=total_num_of_ratings&spirit_style_id=123')
    time.sleep(random.uniform(2,4))
    for i in range(10) :
        try:
            btn = driver.find_elements_by_class_name("name")
            btn[i].click()
            time.sleep(random.uniform(2,4))
            name = driver.find_element_by_css_selector("span.secondary-headline.name")
            name_list.append(name.text)
            try:
                score = driver.find_element_by_css_selector("#main-content > div > div.spirit-show.center-column.js-carousel.vodka-content > div.primary-content > div.tabs > div > div > div.stats-container > div > div > div > div > div.rating-display__value.average-rating > span")
                score_list.append(score.text)
            except:
                score_list.append("none")
            abv = driver.find_element_by_css_selector("#main-content > div > div.spirit-show.center-column.js-carousel.vodka-content > div.primary-content > div.tabs > div > div > div.spirit-show__description-container > div.other-details-container > ul > div > li.detail.abv > div.value")
            abv_list.append(abv.text)
            try:
                des = driver.find_element_by_css_selector("#main-content > div > div.spirit-show.center-column.js-carousel.vodka-content > div.primary-content > div > div > div > div.spirit-show__description-container > div.only-big > p")
                des_list.append(des.text)
                print("설명 입력")
            except:
                des_list.append("none")
                print("설명없음")
            try :
                canvasTemp=driver.find_element_by_css_selector(".js-flavor-profile-chart")
                taste_list.append(canvasTemp.get_attribute('data-flavors'))
            except :
                taste_list.append("none")
                print("오류")
            url = driver.current_url
            res = req.get(url)
            found = re.search(pattern,res.text)
            img_list.append(found.group(1))
            num_list.append(num+1)
            num = num + 1
            driver.back()
            time.sleep(random.uniform(2,4))
        except:
            body = driver.find_element_by_css_selector("body")
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)#
            body.send_keys(Keys.ARROW_DOWN)
            print("다운")
        
    
dic = {"순서" : num_list,"상품명" : name_list, "별점" : score_list, "도수" : abv_list, "설명" : des_list, "맛과향" : taste_list, "이미지" : img_list}
fin = pd.DataFrame(dic)
fin
# Out:
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_6052/1933594892.py:20: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   btn = driver.find_elements_by_class_name("name")
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_6052/1933594892.py:23: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   name = driver.find_element_by_css_selector("span.secondary-headline.name")
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_6052/1933594892.py:26: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   score = driver.find_element_by_css_selector("#main-content > div > div.spirit-show.center-column.js-carousel.vodka-content > div.primary-content > div.tabs > div > div > div.stats-container > div > div > div > div > div.rating-display__value.average-rating > span")
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_6052/1933594892.py:30: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   abv = driver.find_element_by_css_selector("#main-content > div > div.spirit-show.center-column.js-carousel.vodka-content > div.primary-content > div.tabs > div > div > div.spirit-show__description-container > div.other-details-container > ul > div > li.detail.abv > div.value")
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_6052/1933594892.py:33: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   des = driver.find_element_by_css_selector("#main-content > div > div.spirit-show.center-column.js-carousel.vodka-content > div.primary-content > div > div > div > div.spirit-show__description-container > div.only-big > p")
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_6052/1933594892.py:40: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   canvasTemp=driver.find_element_by_css_selector(".js-flavor-profile-chart")
# 설명 입력
# 설명 입력
# 설명 입력
# 설명 입력
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_6052/1933594892.py:54: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   body = driver.find_element_by_css_selector("body")
# 다운
# 설명 입력
# 설명 입력
# 설명 입력
# 설명 입력
# 설명 입력
# 설명 입력
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 다운
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 다운
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명없음
# 오류
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 다운
# 설명없음
# 오류
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 설명없음
# 오류
# 설명 입력
# 설명 입력
# 설명 입력
# 설명 입력
# 오류
# 다운
# 설명 입력
# 설명 입력
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 설명없음
# 오류
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명없음
# 오류
# 다운
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 오류
# 설명없음
# 오류
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 오류
# 다운
# 설명 입력
# 설명없음
# 오류
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 오류
# 다운
# 설명 입력
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명없음
# 오류
# 다운
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 오류
# 다운
# 설명 입력
# 설명 입력
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 다운
# 설명 입력
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 다운
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명 입력
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명 입력
# 오류
# 설명 입력
# 오류
# 다운
# 설명 입력
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명 입력
# 설명없음
# 오류
# 설명없음
# 오류
# 설명 입력
# 오류
# 설명없음
# 오류
# 다운
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 설명 입력
# 오류
# 설명없음
# 오류
# 다운
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 다운
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명 입력
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 다운
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 다운
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명 입력
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 다운
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 다운
# 설명 입력
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명 입력
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 다운
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명 입력
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 다운
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 다운
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명 입력
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 다운
# 설명 입력
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 다운
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명 입력
# 설명 입력
# 오류
# 설명없음
# 오류
# 다운
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 다운
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 설명없음
# 오류
# 설명없음
# 오류
# 다운
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 다운
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명 입력
# 오류
#       순서                    상품명    별점    도수  \
# 0      1           TITO'S VODKA   3.8  40.0
# 1      2          ABSOLUT VODKA   3.1  40.0
# 2      3       GREY GOOSE VODKA  3.78  40.0
# 3      4        KETEL ONE VODKA   3.9  40.0
# 4      5            REYKA VODKA  4.19  40.0
# ..   ...                    ...   ...   ...
# 256  257  CANDELLA Y TOWN VODKA   4.0  40.0
# 257  258         DECADENT VODKA  3.25  40.0
# 258  259                 MISHKA   5.0  40.0
# 259  260       RYE HARBOR VODKA   3.5  40.0
# 260  261      DIRTY DEVIL VODKA   4.5  42.0
#
#                                                     설명  \
# 0    Created by Bertito "Tito" Beveridge, a Texas n...
# 1    Absolut is produced in the town of Åhus in Swe...
# 2    Grey Goose launched in 1997 and is one of the ...
# 3    First launched in 1983, Ketel One is made from...
# 4    Reyka's distillery is located in the town of B...
# ..                                                 ...
# 256                                               none
# 257                                               none
# 258                                               none
# 259                                               none
# 260  Dirty Devil Vodka was created and launched in ...
#
#                                                    맛과향  \
# 0    {"grain":30,"earthy":15,"spicy":35,"herbal":10...
# 1    {"grain":75,"earthy":20,"spicy":15,"herbal":15...
# 2    {"grain":40,"earthy":30,"spicy":30,"herbal":15...
# 3    {"grain":80,"earthy":20,"spicy":35,"herbal":0,...
# 4    {"grain":70,"earthy":20,"spicy":45,"herbal":15...
# ..                                                 ...
# 256                                               none
# 257                                               none
# 258                                               none
# 259                                               none
# 260                                               none
#
#                                                    이미지
# 0    https://ip-distiller.imgix.net/images/spirits/...
# 1    https://ip-distiller.imgix.net/images/spirits/...
# 2    https://ip-distiller.imgix.net/images/spirits/...
# 3    https://ip-distiller.imgix.net/images/spirits/...
# 4    https://ip-distiller.imgix.net/images/spirits/...
# ..                                                 ...
# 256  https://ip-distiller.imgix.net/images/spirits/...
# 257  https://ip-distiller.imgix.net/images/spirits/...
# 258  https://ip-distiller.imgix.net/images/spirits/...
# 259  https://ip-distiller.imgix.net/images/spirits/...
# 260  https://ip-distiller.imgix.net/images/spirits/...
#
# [261 rows x 7 columns]

# %%
'https://distiller.com/search?page='+str(j)+'&sort=total_num_of_ratings&spirit_style_id=123'

# %%
fin.to_csv("distiller-무향보드카최종.csv", encoding="utf-8-sig")
