# %%
from selenium import webdriver as wb
from selenium.webdriver.common.keys import Keys
import time
import random
import requests as req
from bs4 import BeautifulSoup as bs
import re
import pandas as pd

# %%
pattern = re.compile('url\((.*?)\)') 
name_list = [] #이름
score_list = [] #별점
abv_list = [] #도수
des_list = [] #설명
tnote_list = [] #테이스팅 노트
taste_list = [] #맛, 향
img_list = [] # 이미지
num_list = [] #순서
num = 0

driver = wb.Chrome()
driver.maximize_window()
time.sleep(random.uniform(2,4))

for j in range(1,25):
    driver.get('https://distiller.com/search?page='+str(j)+'&sort=total_num_of_ratings&spirit_style_id=104')
    time.sleep(random.uniform(2,4))
    for i in range(10) :
        try:
            btn = driver.find_elements_by_class_name("name")
            btn[i].click()
            time.sleep(random.uniform(2,4))
            name = driver.find_element_by_css_selector("span.secondary-headline.name")
            name_list.append(name.text)
            try:
                score = driver.find_element_by_css_selector("#main-content > div > div.spirit-show.center-column.js-carousel.vodka-content > div.primary-content > div.tabs > div > div > div.stats-container > div > div > div > div > div.rating-display__value.average-rating > span")
                score_list.append(score.text)
            except:
                score_list.append("none")
            abv = driver.find_element_by_css_selector("#main-content > div > div.spirit-show.center-column.js-carousel.vodka-content > div.primary-content > div.tabs > div > div > div.spirit-show__description-container > div.other-details-container > ul > div > li.detail.abv > div.value")
            abv_list.append(abv.text)
            try:
                des = driver.find_element_by_css_selector("#main-content > div > div.spirit-show.center-column.js-carousel.vodka-content > div.primary-content > div > div > div > div.spirit-show__description-container > div.only-big > p")
                des_list.append(des.text)
                print("설명 입력")
            except:
                des_list.append("none")
                print("설명없음")
            try:
                tnote = driver.find_element_by_css_selector('#main-content > div > div.spirit-show.center-column.js-carousel.vodka-content > div.primary-content > div.tabs > div > div > div.details-module.spirit-show__tasting-notes.screened > div.content > p')
                tnote_list.append(tnote.text)
            except:
                tnote_list.append("none")
            try :
                canvasTemp=driver.find_element_by_css_selector(".js-flavor-profile-chart")
                taste_list.append(canvasTemp.get_attribute('data-flavors'))
            except :
                taste_list.append("none")
                print("오류")
            url = driver.current_url
            res = req.get(url)
            found = re.search(pattern,res.text)
            img_list.append(found.group(1))
            num_list.append(num+1)
            num = num + 1
            driver.back()
            time.sleep(random.uniform(2,4))
        except:
            body = driver.find_element_by_css_selector("body")
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)#
            body.send_keys(Keys.ARROW_DOWN)
            print("다운")
        
    
dic = {"순서" : num_list,"상품명" : name_list, "별점" : score_list, "도수" : abv_list, "설명" : des_list, "테이스트노트" : tnote_list, "맛과향" : taste_list, "이미지" : img_list}
fin = pd.DataFrame(dic)
fin
# Out:
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_460/3667258517.py:21: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   btn = driver.find_elements_by_class_name("name")
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_460/3667258517.py:24: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   name = driver.find_element_by_css_selector("span.secondary-headline.name")
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_460/3667258517.py:27: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   score = driver.find_element_by_css_selector("#main-content > div > div.spirit-show.center-column.js-carousel.vodka-content > div.primary-content > div.tabs > div > div > div.stats-container > div > div > div > div > div.rating-display__value.average-rating > span")
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_460/3667258517.py:31: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   abv = driver.find_element_by_css_selector("#main-content > div > div.spirit-show.center-column.js-carousel.vodka-content > div.primary-content > div.tabs > div > div > div.spirit-show__description-container > div.other-details-container > ul > div > li.detail.abv > div.value")
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_460/3667258517.py:34: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   des = driver.find_element_by_css_selector("#main-content > div > div.spirit-show.center-column.js-carousel.vodka-content > div.primary-content > div > div > div > div.spirit-show__description-container > div.only-big > p")
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_460/3667258517.py:41: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   tnote = driver.find_element_by_css_selector('#main-content > div > div.spirit-show.center-column.js-carousel.vodka-content > div.primary-content > div.tabs > div > div > div.details-module.spirit-show__tasting-notes.screened > div.content > p')
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_460/3667258517.py:46: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   canvasTemp=driver.find_element_by_css_selector(".js-flavor-profile-chart")
# 설명 입력
# 오류
# 설명 입력
# 설명없음
# 오류
# 설명 입력
# 오류
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_460/3667258517.py:60: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   body = driver.find_element_by_css_selector("body")
# 다운
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 설명없음
# 오류
# 설명 입력
# 오류
# 다운
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 오류
# 다운
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명없음
# 오류
# 다운
# 설명 입력
# 오류
# 설명없음
# 오류
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 설명 입력
# 설명없음
# 오류
# 설명 입력
# 오류
# 설명없음
# 오류
# 다운
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 오류
# 다운
# 설명 입력
# 오류
# 설명 입력
# 설명없음
# 오류
# 설명없음
# 오류
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 오류
# 다운
# 설명 입력
# 오류
# 설명 입력
# 설명없음
# 오류
# 설명 입력
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 오류
# 다운
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명없음
# 오류
# 설명 입력
# 설명 입력
# 오류
# 다운
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명 입력
# 설명없음
# 오류
# 설명 입력
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 다운
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 오류
# 다운
# 설명 입력
# 설명 입력
# 오류
# 설명없음
# 오류
# 설명 입력
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명 입력
# 오류
# 다운
# 설명없음
# 오류
# 설명없음
# 오류
# 설명 입력
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 오류
# 다운
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 오류
# 다운
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 다운
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 다운
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 다운
# 설명 입력
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명없음
# 오류
# 다운
# 설명 입력
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 설명 입력
# 설명 입력
# 설명 입력
# 설명 입력
# 오류
# 다운
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 오류
# 다운
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 다운
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명 입력
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 다운
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명 입력
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 다운
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명 입력
# 오류
# 다운
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
#       순서                                 상품명    별점    도수  \
# 0      1          ŻUBRÓWKA BISON GRASS VODKA  4.08  40.0
# 1      2                      ABSOLUT CITRON  2.95  40.0
# 2      3          NEW AMSTERDAM PINK WHITNEY  4.09  30.0
# 3      4                     ABSOLUT VANILLA  3.18  40.0
# 4      5               RUSSIAN STANDARD GOLD  4.04  40.0
# ..   ...                                 ...   ...   ...
# 211  212   THREE OLIVES TRIPLE SHOT ESPRESSO  4.25  35.0
# 212  213                               TAAKA  4.25  30.0
# 213  214  SOUTHERN STYLE- SOUTHERN SWEET TEA  0.25  35.0
# 214  215      KOSKENKORVA VODKA 7 BOTANICALS  3.25  37.5
# 215  216   FIREFLY LOWCOUNTRY LEMONADE VODKA   4.5
#
#                                                     설명  \
# 0    This Polish rye-based vodka is flavored with g...
# 1    Citron was first launched in 1988, the second ...
# 2                                                 none
# 3    Absolut Vanilla launched in 2003. It is made u...
# 4    This bottling in the Russian Standard Vodka po...
# ..                                                 ...
# 211                                               none
# 212                                               none
# 213                                               none
# 214                                               none
# 215                                               none
#
#                                                 테이스트노트  \
# 0                                                 none
# 1    "Bright citrus notes greet you on the nose, bu...
# 2                                                 none
# 3                                                 none
# 4                                                 none
# ..                                                 ...
# 211                                               none
# 212                                               none
# 213                                               none
# 214                                               none
# 215                                               none
#
#                                                    맛과향  \
# 0                                                 none
# 1    {"grain":40,"earthy":15,"spicy":15,"herbal":0,...
# 2                                                 none
# 3                                                 none
# 4                                                 none
# ..                                                 ...
# 211                                               none
# 212                                               none
# 213                                               none
# 214                                               none
# 215                                               none
#
#                                                    이미지
# 0    https://ip-distiller.imgix.net/images/spirits/...
# 1    https://ip-distiller.imgix.net/images/spirits/...
# 2    https://ip-distiller.imgix.net/images/spirits/...
# 3    https://ip-distiller.imgix.net/images/spirits/...
# 4    https://ip-distiller.imgix.net/images/spirits/...
# ..                                                 ...
# 211  https://ip-distiller.imgix.net/images/spirits/...
# 212  https://ip-distiller.imgix.net/images/spirits/...
# 213  https://ip-distiller.imgix.net/images/spirits/...
# 214  https://ip-distiller.imgix.net/images/spirits/...
# 215  https://ip-distiller.imgix.net/images/spirits/...
#
# [216 rows x 8 columns]

# %%
fin
# Out:
#       순서                         상품명    별점    도수  \
# 0      1  ŻUBRÓWKA BISON GRASS VODKA  4.08  40.0
# 1      2              ABSOLUT CITRON  2.95  40.0
# 2      3  NEW AMSTERDAM PINK WHITNEY  4.09  30.0
# 3      4             ABSOLUT VANILLA  3.18  40.0
# 4      5       RUSSIAN STANDARD GOLD  4.04  40.0
# ..   ...                         ...   ...   ...
# 454  455            360 GLAZED DONUT  none  35.0
# 455  456                   360 GRAPE  none  35.0
# 456  457           360 RED RASPBERRY  none  35.0
# 457  458                   360 MANGO  none  35.0
# 458  459               SVEDKA COLADA  none  35.0
#
#                                                     설명  \
# 0    This Polish rye-based vodka is flavored with g...
# 1    Citron was first launched in 1988, the second ...
# 2                                                 none
# 3    Absolut Vanilla launched in 2003. It is made u...
# 4    This bottling in the Russian Standard Vodka po...
# ..                                                 ...
# 454  This donut-flavored vodka is made with natural...
# 455  This grape-flavored vodka is made with natural...
# 456  This raspberry-flavored vodka is made with nat...
# 457  This mango-flavored vodka is made with natural...
# 458  Introduced in 2012, this flavored vodka uses S...
#
#                                                    맛과향  \
# 0                                                 none
# 1    {"grain":40,"earthy":15,"spicy":15,"herbal":0,...
# 2                                                 none
# 3                                                 none
# 4                                                 none
# ..                                                 ...
# 454                                               none
# 455                                               none
# 456                                               none
# 457                                               none
# 458                                               none
#
#                                                    이미지
# 0    https://ip-distiller.imgix.net/images/spirits/...
# 1    https://ip-distiller.imgix.net/images/spirits/...
# 2    https://ip-distiller.imgix.net/images/spirits/...
# 3    https://ip-distiller.imgix.net/images/spirits/...
# 4    https://ip-distiller.imgix.net/images/spirits/...
# ..                                                 ...
# 454  https://ip-distiller.imgix.net/images/spirits/...
# 455  https://ip-distiller.imgix.net/images/spirits/...
# 456  https://ip-distiller.imgix.net/images/spirits/...
# 457  https://ip-distiller.imgix.net/images/spirits/...
# 458  https://ip-distiller.imgix.net/images/spirits/...
#
# [459 rows x 7 columns]

# %%
fin.to_csv("distiller-향보드카최종.csv", encoding="utf-8-sig")
