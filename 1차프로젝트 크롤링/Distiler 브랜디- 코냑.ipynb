# %%
from selenium import webdriver as wb
from selenium.webdriver.common.keys import Keys
import time
import random
import requests as req
from bs4 import BeautifulSoup as bs
import re
import pandas as pd

# %%
pattern = re.compile('url\((.*?)\)') 
name_list = [] #이름
score_list = [] #별점
abv_list = [] #도수
des_list = [] #설명
tnote_list = [] #테이스팅 노트
taste_list = [] #맛, 향
img_list = [] # 이미지
num_list = [] #순서
num = 0

driver = wb.Chrome()
driver.maximize_window()
time.sleep(random.uniform(2,4))

for j in range(1,24):
    driver.get('https://distiller.com/search?page='+str(j)+'&sort=total_num_of_ratings&spirit_style_id=126')
    time.sleep(random.uniform(2,4))
    for i in range(10) :
        try:
            btn = driver.find_elements_by_class_name("name")
            btn[i].click()
            time.sleep(random.uniform(2,4))
            name = driver.find_element_by_css_selector("span.secondary-headline.name")
            name_list.append(name.text)
            try:
                score = driver.find_element_by_css_selector('div.rating-display__value.average-rating>span')
                score_list.append(score.text)
            except:
                score_list.append("none")
            try:
                abv = driver.find_element_by_css_selector('li.detail.abv>div.value')
                abv_list.append(abv.text)
            except:
                abv_list.append("none")
            try:
                des = driver.find_element_by_css_selector('div.only-big>p.description')
                des_list.append(des.text)
                print("설명 입력")
            except:
                des_list.append("none")
                print("설명없음")
            try:
                tnote = driver.find_element_by_css_selector('div.content>p')
                tnote_list.append(tnote.text)
            except:
                tnote_list.append("none")
            try :
                canvasTemp=driver.find_element_by_css_selector(".js-flavor-profile-chart")
                taste_list.append(canvasTemp.get_attribute('data-flavors'))
            except :
                taste_list.append("none")
                print("오류")
            url = driver.current_url
            res = req.get(url)
            found = re.search(pattern,res.text)
            img_list.append(found.group(1))
            num_list.append(num+1)
            num = num + 1
            driver.back()
            time.sleep(random.uniform(2,4))
        except:
            body = driver.find_element_by_css_selector("body")
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)#
            body.send_keys(Keys.ARROW_DOWN)
            print("다운")
        
    
dic = {"순서" : num_list,"상품명" : name_list, "별점" : score_list, "도수" : abv_list, "설명" : des_list, "테이스트노트" : tnote_list, "맛과향" : taste_list, "이미지" : img_list}
fin = pd.DataFrame(dic)
fin
# Out:
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_16404/3218666112.py:21: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   btn = driver.find_elements_by_class_name("name")
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_16404/3218666112.py:24: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   name = driver.find_element_by_css_selector("span.secondary-headline.name")
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_16404/3218666112.py:27: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   score = driver.find_element_by_css_selector('div.rating-display__value.average-rating>span')
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_16404/3218666112.py:32: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   abv = driver.find_element_by_css_selector('li.detail.abv>div.value')
# ...

# %%
img_list
# Out:
# ['https://ip-distiller.imgix.net/images/spirits/3a3d4fe0-6c78-0133-24a4-2a2fce82570d/hennessy_vs_cognac_tile.jpg?w=280&amp;h=280&amp;mark-w=70&amp;mark-h=70&amp;fit=crop&amp;crop=right&amp;mark-align=top,left&amp;mark-pad=0&amp;mark=',
#  'https://ip-distiller.imgix.net/images/spirits/4cdc5800-6c79-0133-3984-4627d8451793/remy_martin_vsop_cognac_tile.jpg?w=280&amp;h=280&amp;mark-w=70&amp;mark-h=70&amp;fit=crop&amp;crop=right&amp;mark-align=top,left&amp;mark-pad=0&amp;mark=',
#  'https://ip-distiller.imgix.net/images/spirits/cbaf0210-6bd4-0133-1394-16d3e9a61cc7/remy_martin_1738_accord_royal_cognac_tile.jpg?w=280&amp;h=280&amp;mark-w=70&amp;mark-h=70&amp;fit=crop&amp;crop=right&amp;mark-align=top,left&amp;mark-pad=0&amp;mark=',
#  'https://ip-distiller.imgix.net/images/spirits/7691fcc0-7772-0133-2071-22ea1e38f468/_Hennessy_Privilege_VSOP_Cognac_tile.jpg?w=280&amp;h=280&amp;mark-w=70&amp;mark-h=70&amp;fit=crop&amp;crop=right&amp;mark-align=top,left&amp;mark-pad=0&amp;mark=',
# ...

# %%
fin.to_csv("distiller 브랜디- 코냑.csv", encoding="utf-8-sig")

# %%
driver = wb.Chrome()
driver.get('https://distiller.com/search?sort=total_num_of_ratings&spirit_style_id=126')

# %%
score = driver.find_element_by_css_selector('div.rating-display__value.average-rating>span')
score.text
# Out:
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_16404/412147032.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   score = driver.find_element_by_css_selector('div.rating-display__value.average-rating>span')
# '4.14'

# %%
abv = driver.find_element_by_css_selector('li.detail.abv>div.value')
abv.text
# Out:
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_16404/4079250759.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   abv = driver.find_element_by_css_selector('li.detail.abv>div.value')
# '45.0'

# %%
des = driver.find_element_by_css_selector('div.only-big>p.description')
des.text
# Out:
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_16404/1927873914.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   des = driver.find_element_by_css_selector('div.only-big>p.description')
# 'Released in 2011,1840 Original Formula was created as a collaboration between Pierre Ferrand owner, Alexandre Gabriel, their cellar master, Christian Guerin, and cocktail historian, Dave Wondrich. Using a rare 19th century cognac, Pinet-Castillon Cognac from 1840 as a base, this product is designed to replicate what would have been used then in cocktails and punches. Its youthful fruity and floral character along with its higher proof for added oomph makes it stand out from other VS cognacs.'

# %%
tnote = driver.find_element_by_css_selector('div.content>p')
tnote.text
# Out:
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_16404/2735946816.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   tnote = driver.find_element_by_css_selector('div.content>p')
# '"The aromas are a pleasant mix without one dominating the other of ripe pears, wax, green grapes, and delicate floral notes. These notes don\'t differ much on the palate but there are added elements of mint and crushed peanuts on its creamy texture. Though this isn\'t really designed as a sipping cognac, you could certainly do worse."'
