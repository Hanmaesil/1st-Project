# %%
from selenium import webdriver as wb
from selenium.webdriver.common.keys import Keys
import time
import random
import requests as req
from bs4 import BeautifulSoup as bs
import re
import pandas as pd

# %%
pattern = re.compile('url\((.*?)\)') 
name_list = [] #이름
score_list = [] #별점
abv_list = [] #도수
des_list = [] #설명
taste_list = [] #맛, 향
img_list = [] # 이미지
num_list = [] #순서
num = 0

driver = wb.Chrome()
driver.maximize_window()
time.sleep(random.uniform(2,4))

for j in range(1,13):
    driver.get('https://distiller.com/search?page='+str(j)+'&sort=total_num_of_ratings&spirit_style_id=142')
    time.sleep(random.uniform(2,4))
    for i in range(10) :
        try:
            btn = driver.find_elements_by_class_name("name")
            btn[i].click()
            time.sleep(random.uniform(2,4))
            name = driver.find_element_by_css_selector("span.secondary-headline.name")
            name_list.append(name.text)
            try:
                score = driver.find_element_by_css_selector('#main-content > div > div.spirit-show.center-column.js-carousel.liqueur-content > div.primary-content > div > div > div > div.stats-container > div > div > div > div > div.rating-display__value.average-rating > span')
                score_list.append(score.text)
            except:
                score_list.append("none")
            abv = driver.find_element_by_css_selector('#main-content > div > div.spirit-show.center-column.js-carousel.liqueur-content > div.primary-content > div > div > div > div.spirit-show__description-container > div.other-details-container > ul > div > li.detail.abv > div.value')
            abv_list.append(abv.text)
            try:
                des = driver.find_element_by_css_selector('#main-content > div > div.spirit-show.center-column.js-carousel.liqueur-content > div.primary-content > div > div > div > div.spirit-show__description-container > div.only-big > p')
                des_list.append(des.text)
                print("설명 입력")
            except:
                des_list.append("none")
                print("설명없음")
            try :
                canvasTemp=driver.find_element_by_css_selector(".js-flavor-profile-chart")
                taste_list.append(canvasTemp.get_attribute('data-flavors'))
            except :
                taste_list.append("none")
                print("오류")
            url = driver.current_url
            res = req.get(url)
            found = re.search(pattern,res.text)
            img_list.append(found.group(1))
            num_list.append(num+1)
            num = num + 1
            driver.back()
            time.sleep(random.uniform(2,4))
        except:
            body = driver.find_element_by_css_selector("body")
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)#
            body.send_keys(Keys.ARROW_DOWN)
            print("다운")
        
    
dic = {"순서" : num_list,"상품명" : name_list, "별점" : score_list, "도수" : abv_list, "설명" : des_list, "맛과향" : taste_list, "이미지" : img_list}
fin = pd.DataFrame(dic)
fin
# Out:
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_13540/4175449597.py:20: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   btn = driver.find_elements_by_class_name("name")
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_13540/4175449597.py:23: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   name = driver.find_element_by_css_selector("span.secondary-headline.name")
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_13540/4175449597.py:26: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   score = driver.find_element_by_css_selector('#main-content > div > div.spirit-show.center-column.js-carousel.liqueur-content > div.primary-content > div > div > div > div.stats-container > div > div > div > div > div.rating-display__value.average-rating > span')
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_13540/4175449597.py:30: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   abv = driver.find_element_by_css_selector('#main-content > div > div.spirit-show.center-column.js-carousel.liqueur-content > div.primary-content > div > div > div > div.spirit-show__description-container > div.other-details-container > ul > div > li.detail.abv > div.value')
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_13540/4175449597.py:33: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   des = driver.find_element_by_css_selector('#main-content > div > div.spirit-show.center-column.js-carousel.liqueur-content > div.primary-content > div > div > div > div.spirit-show__description-container > div.only-big > p')
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_13540/4175449597.py:40: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   canvasTemp=driver.find_element_by_css_selector(".js-flavor-profile-chart")
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 오류
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_13540/4175449597.py:54: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   body = driver.find_element_by_css_selector("body")
# 다운
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명없음
# 오류
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명없음
# 오류
# 설명 입력
# 오류
# 다운
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명 입력
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 다운
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명 입력
# 설명없음
# 오류
# 다운
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 다운
# 설명없음
# 오류
# 설명없음
# 오류
# 설명 입력
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 다운
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명 입력
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 다운
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 다운
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 다운
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 다운
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 다운
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 다운
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
#       순서                               상품명    별점     도수  \
# 0      1     JACK DANIEL'S TENNESSEE HONEY  2.82   35.0
# 1      2        WILD TURKEY AMERICAN HONEY  2.94   35.5
# 2      3                    JIM BEAM HONEY  2.56   35.0
# 3      4                    JIM BEAM MAPLE  2.56   35.0
# 4      5  WILD TURKEY AMERICAN HONEY STING  3.15  35.35
# ..   ...                               ...   ...    ...
# 103  104         TETTERIS MASTIHA OF CHIOS  2.75   24.0
# 104  105                   KOSTEAS MASTIHA  3.25   17.0
# 105  106                       WALDHIMBEER   3.0
# 106  107       MOLLY’S COCONUT IRISH CREAM   3.5
# 107  108          CHAMAREL VANILLA LIQUEUR   4.0   35.0
#
#                                                     설명  \
# 0    Jack Daniel's Tennessee Honey is made from a b...
# 1    Wild Turkey American Honey is a 71-proof lique...
# 2    Jim Beam Honey is made with real honey and nat...
# 3    Jim Beam Maple is made by infusing maple lique...
# 4    To create this whiskey liqueur, Wild Turkey Bo...
# ..                                                 ...
# 103                                               none
# 104                                               none
# 105                                               none
# 106                                               none
# 107                                               none
#
#                                                    맛과향  \
# 0                                                 none
# 1                                                 none
# 2    {"sweet":90,"rich":60,"spicy":0,"herbal":10,"f...
# 3                                                 none
# 4                                                 none
# ..                                                 ...
# 103                                               none
# 104                                               none
# 105                                               none
# 106                                               none
# 107                                               none
#
#                                                    이미지
# 0    https://ip-distiller.imgix.net/images/spirits/...
# 1    https://ip-distiller.imgix.net/images/spirits/...
# 2    https://ip-distiller.imgix.net/images/spirits/...
# 3    https://ip-distiller.imgix.net/images/spirits/...
# 4    https://ip-distiller.imgix.net/images/spirits/...
# ..                                                 ...
# 103  https://ip-distiller.imgix.net/images/spirits/...
# 104  https://ip-distiller.imgix.net/images/spirits/...
# 105  https://ip-distiller.imgix.net/images/spirits/...
# 106  https://ip-distiller.imgix.net/images/spirits/...
# 107  https://ip-distiller.imgix.net/images/spirits/...
#
# [108 rows x 7 columns]

# %%
fin.to_csv("distiller-기타리큐르.csv", encoding="utf-8-sig")
