# %%
from selenium import webdriver as wb
from selenium.webdriver.common.keys import Keys
import time
import random
import requests as req
from bs4 import BeautifulSoup as bs
import re
import pandas as pd

# %%
pattern = re.compile('url\((.*?)\)') 
name_list = [] #이름
score_list = [] #별점
abv_list = [] #도수
des_list = [] #설명
tnote_list = [] #테이스팅 노트
taste_list = [] #맛, 향
img_list = [] # 이미지
num_list = [] #순서
jtype_list= [] #타입
num = 0

driver = wb.Chrome()
driver.maximize_window()
time.sleep(random.uniform(2,4))

for j in range(1,46):
    driver.get('https://distiller.com/search?page='+str(j)+'&sort=total_num_of_ratings&spirit_category_id=25')
    time.sleep(random.uniform(2,4))
    for i in range(10) :
        try:
            btn = driver.find_elements_by_class_name("name")
            btn[i].click()
            time.sleep(random.uniform(2,4))
            name = driver.find_element_by_css_selector("span.secondary-headline.name")
            name_list.append(name.text)
            try:
                jtype = driver.find_element_by_css_selector('div.secondary-details>h2.ultra-mini-headline.type')
                jtype_list.append(jtype.text)
            except:
                jtype_list.append("none")
            try:
                score = driver.find_element_by_css_selector('div.rating-display__value.average-rating>span')
                score_list.append(score.text)
            except:
                score_list.append("none")
            try:
                abv = driver.find_element_by_css_selector('li.detail.abv>div.value')
                abv_list.append(abv.text)
            except:
                abv_list.append("none")
            try:
                des = driver.find_element_by_css_selector('div.only-big>p.description')
                des_list.append(des.text)
                print("설명 입력")
            except:
                des_list.append("none")
                print("설명없음")
            try:
                tnote = driver.find_element_by_css_selector('div.content>p')
                tnote_list.append(tnote.text)
            except:
                tnote_list.append("none")
            try :
                canvasTemp=driver.find_element_by_css_selector(".js-flavor-profile-chart")
                taste_list.append(canvasTemp.get_attribute('data-flavors'))
            except :
                taste_list.append("none")
                print("오류")
            url = driver.current_url
            res = req.get(url)
            found = re.search(pattern,res.text)
            img_list.append(found.group(1))
            num_list.append(num+1)
            num = num + 1
            driver.back()
            time.sleep(random.uniform(2,4))
        except:
            body = driver.find_element_by_css_selector("body")
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)#
            body.send_keys(Keys.ARROW_DOWN)
            print("다운")
        
    
dic = {"순서" : num_list,"상품명" : name_list, "별점" : score_list, "도수" : abv_list, "타입" : jtype_list, "설명" : des_list, "테이스트노트" : tnote_list, "맛과향" : taste_list, "이미지" : img_list}
fin = pd.DataFrame(dic)
fin
# Out:
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_17824/3460219842.py:22: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   btn = driver.find_elements_by_class_name("name")
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_17824/3460219842.py:25: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   name = driver.find_element_by_css_selector("span.secondary-headline.name")
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_17824/3460219842.py:28: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   jtype = driver.find_element_by_css_selector('div.secondary-details>h2.ultra-mini-headline.type')
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_17824/3460219842.py:33: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   score = driver.find_element_by_css_selector('div.rating-display__value.average-rating>span')
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_17824/3460219842.py:38: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   abv = driver.find_element_by_css_selector('li.detail.abv>div.value')
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_17824/3460219842.py:43: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   des = driver.find_element_by_css_selector('div.only-big>p.description')
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_17824/3460219842.py:50: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   tnote = driver.find_element_by_css_selector('div.content>p')
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_17824/3460219842.py:55: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   canvasTemp=driver.find_element_by_css_selector(".js-flavor-profile-chart")
# 설명 입력
# 설명 입력
# 설명 입력
# 설명 입력
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_17824/3460219842.py:69: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   body = driver.find_element_by_css_selector("body")
# 다운
# 설명 입력
# 설명 입력
# 설명 입력
# 설명 입력
# 설명 입력
# 설명 입력
# 설명 입력
# 설명 입력
# 설명 입력
# 다운
# 설명 입력
# 설명 입력
# 설명 입력
# 설명 입력
# 설명 입력
# 설명 입력
# 설명 입력
# 설명 입력
# 설명 입력
# 다운
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 설명 입력
# 설명 입력
# 다운
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 설명 입력
# 설명 입력
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 다운
# 설명 입력
# 설명 입력
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 설명 입력
# 설명 입력
# 설명 입력
# 다운
# 설명 입력
# 설명 입력
# 설명 입력
# 설명 입력
# 설명 입력
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 다운
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 설명 입력
# 설명 입력
# 설명 입력
# 다운
# 설명 입력
# 설명 입력
# 설명 입력
# 설명 입력
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 설명 입력
# 다운
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 설명없음
# 오류
# 설명 입력
# 오류
# 설명 입력
# 다운
# 설명 입력
# 설명없음
# 오류
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 오류
# 다운
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 설명 입력
# 설명없음
# 오류
# 설명없음
# 오류
# 설명 입력
# 다운
# 설명없음
# 오류
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 오류
# 다운
# 설명 입력
# 설명 입력
# 설명 입력
# 설명 입력
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 다운
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 설명 입력
# 설명없음
# 오류
# 다운
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 설명 입력
# 설명 입력
# 설명 입력
# 오류
# 다운
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 설명 입력
# 다운
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 설명 입력
# 설명 입력
# 오류
# 설명없음
# 오류
# 설명 입력
# 설명 입력
# 오류
# 다운
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 다운
# 설명 입력
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 설명없음
# 오류
# 다운
# 설명없음
# 오류
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 다운
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명없음
# 오류
# 설명 입력
# 오류
# 설명 입력
# 설명없음
# 오류
# 설명 입력
# 설명 입력
# 다운
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 다운
# 설명 입력
# 설명 입력
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명 입력
# 오류
# 설명 입력
# 설명없음
# 오류
# 설명 입력
# 오류
# 다운
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 설명없음
# 오류
# 설명없음
# 오류
# 다운
# 설명없음
# 오류
# 설명없음
# 오류
# 설명 입력
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명 입력
# 설명 입력
# 설명없음
# 오류
# 다운
# 설명 입력
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명 입력
# 오류
# 다운
# 설명 입력
# 설명 입력
# 설명 입력
# 설명 입력
# 설명 입력
# 설명 입력
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 다운
# 설명없음
# 오류
# 설명 입력
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 다운
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명 입력
# 오류
# 설명 입력
# 오류
# 다운
# 설명 입력
# 설명 입력
# 설명 입력
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 설명 입력
# 설명 입력
# 다운
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 설명없음
# 오류
# 다운
# 설명없음
# 오류
# 설명 입력
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명 입력
# 설명 입력
# 오류
# 설명없음
# 오류
# 다운
# 설명없음
# 오류
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 설명 입력
# 다운
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 설명 입력
# 설명 입력
# 설명없음
# 오류
# 다운
# 설명 입력
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명 입력
# 오류
# 설명없음
# 오류
# 다운
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명 입력
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명 입력
# 오류
# 다운
# 설명 입력
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명 입력
# 오류
# 다운
# 설명없음
# 오류
# 설명 입력
# 오류
# 설명 입력
# 설명없음
# 오류
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 설명없음
# 오류
# 설명없음
# 오류
# 다운
# 설명 입력
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 다운
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 설명 입력
# 오류
# 다운
# 설명 입력
# 설명 입력
# 오류
# 설명 입력
# 설명 입력
# 설명없음
# 오류
# 설명없음
# 오류
# 설명 입력
# 설명없음
# 오류
# 설명 입력
# 오류
# 다운
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명 입력
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 다운
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 다운
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 다운
# 설명없음
# 오류
# 설명없음
# 오류
# 설명 입력
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
#       순서                                      상품명    별점    도수  \
# 0      1                        MONKEY 47 DRY GIN   4.6  47.0
# 1      2                         THE BOTANIST GIN  4.33  46.0
# 2      3                   HENDRICK'S GIN (41.4%)  4.19  41.4
# 3      4                BOMBAY SAPPHIRE GIN (47%)  3.62  47.0
# 4      5         TANQUERAY LONDON DRY GIN (47.3%)  3.47  47.3
# ..   ...                                      ...   ...   ...
# 400  401                                PANORAMIX  3.06  42.0
# 401  402             BENHAM’S BARREL FINISHED GIN  3.44  48.0
# 402  403        SAKURAO ORIGINAL JAPANESE DRY GIN  3.88  47.0
# 403  404                               REID’S GIN  3.81
# 404  405  NEWFOUNDLAND DISTILLERY CO. SEAWEED GIN  4.47  40.0
#
#                   타입                                                 설명  \
# 0         MODERN GIN  Hailing from Germany’s Black Forest, Monkey 47...
# 1         MODERN GIN  If you're not a Scotch whisky drinker, you ver...
# 2         MODERN GIN  Hendrick's launched in 2001 and is distilled i...
# 3     LONDON DRY GIN  Bombay Sapphire was first introduced in 1987. ...
# 4     LONDON DRY GIN  Tanqueray is named after its founder, Charles ...
# ..               ...                                                ...
# 400     COMPOUND GIN                                               none
# 401  BARREL-AGED GIN                                               none
# 402       MODERN GIN  Sakurao Original Japanese Dry Gin is not only ...
# 403       MODERN GIN                                               none
# 404    DISTILLED GIN                                               none
#
#                                                 테이스트노트  \
# 0    "Monkey 47 is an exquisite gin that pushes the...
# 1    "With all of the botanicals used, it can take ...
# 2    "The rose scent comes through loud and clear o...
# 3    "The delicate botanicals may surprise you. The...
# 4    "There's a big pop coriander along with the ju...
# ..                                                 ...
# 400                                               none
# 401                                               none
# 402                                               none
# 403                                               none
# 404                                               none
#
#                                                    맛과향  \
# 0    {"juniper":20,"earthy":20,"spicy":78,"herbal":...
# 1    {"juniper":35,"earthy":20,"spicy":30,"herbal":...
# 2    {"juniper":45,"earthy":25,"spicy":60,"herbal":...
# 3    {"juniper":50,"earthy":60,"spicy":75,"herbal":...
# 4    {"juniper":75,"earthy":60,"spicy":75,"herbal":...
# ..                                                 ...
# 400                                               none
# 401                                               none
# 402                                               none
# 403                                               none
# 404                                               none
#
#                                                    이미지
# 0    https://ip-distiller.imgix.net/images/spirits/...
# 1    https://ip-distiller.imgix.net/images/spirits/...
# 2    https://ip-distiller.imgix.net/images/spirits/...
# 3    https://ip-distiller.imgix.net/images/spirits/...
# 4    https://ip-distiller.imgix.net/images/spirits/...
# ..                                                 ...
# 400  https://ip-distiller.imgix.net/images/spirits/...
# 401  https://ip-distiller.imgix.net/images/spirits/...
# 402  https://ip-distiller.imgix.net/images/spirits/...
# 403  https://ip-distiller.imgix.net/images/spirits/...
# 404  https://ip-distiller.imgix.net/images/spirits/...
#
# [405 rows x 9 columns]

# %%
fin.to_csv("distiller 진.csv", encoding="utf-8-sig")
