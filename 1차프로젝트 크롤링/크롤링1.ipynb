# %%
from selenium import webdriver as wb
from selenium.webdriver.common.keys import Keys
import time
import requests as req
from bs4 import BeautifulSoup as bs
import re
import pandas as pd

# %%
driver = wb.Chrome()
driver.get("https://distiller.com/search?spirit_style_id=104")
#영어 번역 먼저 해줄 것

# %%
btn = driver.find_elements_by_css_selector("div.name")
btn[0].click()

# %%
pattern = re.compile('url\((.*?)\)') 
name_list = [] #이름
score_list = [] #별점
abv_list = [] #도수
des_list = [] #설명
taste_list = [] #맛, 향
img_list = [] # 이미지


driver = wb.Chrome()
time.sleep(2)
driver.get("https://distiller.com/search?spirit_style_id=104")
time.sleep(2)

for i in range(10) :
    name = driver.find_element_by_css_selector("span.secondary-headline.name")
    name_list.append(name.text)
    score = driver.find_element_by_css_selector("#main-content > div > div.spirit-show.center-column.js-carousel.vodka-content > div.primary-content > div.tabs > div > div > div.stats-container > div > div > div > div > div.rating-display__value.average-rating > span")
    score_list.append(score.text)
    abv = driver.find_element_by_css_selector("#main-content > div > div.spirit-show.center-column.js-carousel.vodka-content > div.primary-content > div.tabs > div > div > div.spirit-show__description-container > div.other-details-container > ul > div > li.detail.abv > div.value")
    abv_list.append(abv.text)
    des = driver.find_element_by_css_selector("#main-content > div > div.spirit-show.center-column.js-carousel.vodka-content > div.primary-content > div.tabs > div > div > div.spirit-show__description-container > div.other-details-container > ul > li.detail.whiskey-style > div.value")
    des_list.append(des.text)
    canvasTemp=driver.find_element_by_css_selector(".js-flavor-profile-chart")
    taste_list.append(canvasTemp.get_attribute('data-flavors'))
    url = driver.current_url
    res = req.get(url)
    found = re.search(pattern,res.text)
    img_list.append(found.group(1))
    driver.back()

# %%
#이름
name = driver.find_element_by_css_selector("span.secondary-headline.name")
name.text

# %%
#도수
abv = driver.find_element_by_css_selector("#main-content > div > div.spirit-show.center-column.js-carousel.vodka-content > div.primary-content > div.tabs > div > div > div.spirit-show__description-container > div.other-details-container > ul > div > li.detail.abv > div.value")
abv.text

# %%
#설명
des = driver.find_element_by_css_selector("#main-content > div > div.spirit-show.center-column.js-carousel.vodka-content > div.primary-content > div.tabs > div > div > div.spirit-show__description-container > div.other-details-container > ul > li.detail.whiskey-style > div.value")
des.text

# %%
# 맛,향
# driver = wb.Chrome()
# driver.get("https://distiller.com/spirits/st-george-green-chile-vodka")
canvasTemp=driver.find_element_by_css_selector(".js-flavor-profile-chart")
canvasTemp.get_attribute('data-flavors')
# driver.find_element_by_css_selector(".js-flavor-profile-chart").get_attribute('data-flavors')

# 화이팅 아그리고
# 선생님
# 하나만 더 물어봐도 될까요? 넹넹

# %%
#별점
score = driver.find_element_by_css_selector("#main-content > div > div.spirit-show.center-column.js-carousel.vodka-content > div.primary-content > div.tabs > div > div > div.stats-container > div > div > div > div > div.rating-display__value.average-rating > span")
score.text

# %%
#이미지 경로
pattern = re.compile('url\((.*?)\)') 
url = driver.current_url
res = req.get(url)
found = re.search(pattern,res.text)
print(found.group(1))

# %%
#실험용
https://distiller.com/search?page=3&sort=total_num_of_ratings&spirit_style_id=123

# %%
pattern = re.compile('url\((.*?)\)') 
name_list = [] #이름
score_list = [] #별점
abv_list = [] #도수
des_list = [] #설명
taste_list = [] #맛, 향
img_list = [] # 이미지
num_list = [] #순서


driver = wb.Chrome()
time.sleep(2)
driver.get("https://distiller.com/search?page=3&sort=total_num_of_ratings&spirit_style_id=123")
time.sleep(2)

for i in range(10) :
    btn = driver.find_elements_by_css_selector("div.name")
    btn[i].click()
    time.sleep(2)
    name = driver.find_element_by_css_selector("span.secondary-headline.name")
    name_list.append(name.text)
    score = driver.find_element_by_css_selector("#main-content > div > div.spirit-show.center-column.js-carousel.vodka-content > div.primary-content > div.tabs > div > div > div.stats-container > div > div > div > div > div.rating-display__value.average-rating > span")
    score_list.append(score.text)
    abv = driver.find_element_by_css_selector("#main-content > div > div.spirit-show.center-column.js-carousel.vodka-content > div.primary-content > div.tabs > div > div > div.spirit-show__description-container > div.other-details-container > ul > div > li.detail.abv > div.value")
    abv_list.append(abv.text)
    des = driver.find_element_by_css_selector("#main-content > div > div.spirit-show.center-column.js-carousel.vodka-content > div.primary-content > div.tabs > div > div > div.spirit-show__description-container > div.other-details-container > ul > li.detail.whiskey-style > div.value")
    des_list.append(des.text)
    canvasTemp=driver.find_element_by_css_selector(".js-flavor-profile-chart")
    taste_list.append(canvasTemp.get_attribute('data-flavors'))
    url = driver.current_url
    res = req.get(url)
    found = re.search(pattern,res.text)
    img_list.append(found.group(1))
    num_list.append(i+1)
    driver.back()
    time.sleep(2)
    
    
    
dic = {"순서" : num_list,"상품명" : name_list, "별점" : score_list, "도수" : abv_list, "설명" : des_list, "맛과향" : taste_list, "이미지" : img_list}
fin = pd.DataFrame(dic)

# %%
pattern = re.compile('url\((.*?)\)') 
name_list = [] #이름
score_list = [] #별점
abv_list = [] #도수
des_list = [] #설명
taste_list = [] #맛, 향
img_list = [] # 이미지
num_list = [] #순서


driver = wb.Chrome()
time.sleep(2)
driver.get("https://distiller.com/search?page=3&sort=total_num_of_ratings&spirit_style_id=123")
time.sleep(2)

for i in range(100) :
    btn = driver.find_elements_by_css_selector("li.spirit.vodka-content")
    btn[i].click()
    time.sleep(2)
    name = driver.find_element_by_css_selector("span.secondary-headline.name")
    name_list.append(name.text)
    score = driver.find_element_by_css_selector("#main-content > div > div.spirit-show.center-column.js-carousel.vodka-content > div.primary-content > div.tabs > div > div > div.stats-container > div > div > div > div > div.rating-display__value.average-rating > span")
    score_list.append(score.text)
    abv = driver.find_element_by_css_selector("#main-content > div > div.spirit-show.center-column.js-carousel.vodka-content > div.primary-content > div.tabs > div > div > div.spirit-show__description-container > div.other-details-container > ul > div > li.detail.abv > div.value")
    abv_list.append(abv.text)
    des = driver.find_element_by_css_selector("#main-content > div > div.spirit-show.center-column.js-carousel.vodka-content > div.primary-content > div.tabs > div > div > div.spirit-show__description-container > div.other-details-container > ul > li.detail.whiskey-style > div.value")
    des_list.append(des.text)
    try :
        canvasTemp=driver.find_element_by_css_selector(".js-flavor-profile-chart")
        taste_list.append(canvasTemp.get_attribute('data-flavors'))
    except :
        taste_list.append("")
        print("오류")
    url = driver.current_url
    res = req.get(url)
    found = re.search(pattern,res.text)
    img_list.append(found.group(1))
    num_list.append(i+1)
    driver.back()
    time.sleep(2)
    
    
    
dic = {"순서" : num_list,"상품명" : name_list, "별점" : score_list, "도수" : abv_list, "설명" : des_list, "맛과향" : taste_list, "이미지" : img_list}
fin = pd.DataFrame(dic)

# %%
ㅋㅋㅋㅋ이제 되는거 같고 왼쪽에 이제 요소 클릭부분 잡아주시면 될 거 같아요
아마 단순 오타였던 거 같아요! 저 고친거 오타밖에 없어요! 아 ㅎㅎ
그리고 선생님
이게 영어사이트인데
혹시 크롤링하면서 번역도 할수 있나요?
api사용하면 가능할 거 같은데용?
크롤링 다 하고 나서
번역하는 함수하나 만들어서 돌리면 될 거 같아요!
그러면 여기 for문에 넣는게 좋나요 아니면 크롤링 끝나고 하는게 좋나요?
음 사실 성능의 차이를 좀 살펴보는게 좋을 거 같은데
저라면 일단 기능단위로 나눌 거 같아요
크롤링 코드 따로 놔두고
번역하는 코드 따로 놔둬서
합쳐서 쓸 수 있게끔! 그게 나중에
에러 발생해도 고치기 쉽거든요!
그럼 크롤링 먼저 돌리고 따로 번역하는 코드 만들어서 하는게 좋다는 건가요>
좋다는 아니고 저라면 그렇게 했을거다? 정도?ㅎㅎㅎㅎ
성능상 좋고 나쁘고 그런거 해봐야아는거니까요!!!
정말 감사합니다!! ㅎㅎ

# %%
fin

# %%
pattern = re.compile('url\((.*?)\)') 
name_list = [] #이름
score_list = [] #별점
abv_list = [] #도수
des_list = [] #설명
taste_list = [] #맛, 향
img_list = [] # 이미지
num_list = [] #순서


driver = wb.Chrome()
time.sleep(2)
driver.get("https://distiller.com/search?page=3&sort=total_num_of_ratings&spirit_style_id=123")
time.sleep(2)

# %%
for i in range(10) :
    btn = driver.find_elements_by_class_name("name")
    btn[i].click()
    time.sleep(2)
    name = driver.find_element_by_css_selector("span.secondary-headline.name")
    name_list.append(name.text)
    score = driver.find_element_by_css_selector("#main-content > div > div.spirit-show.center-column.js-carousel.vodka-content > div.primary-content > div.tabs > div > div > div.stats-container > div > div > div > div > div.rating-display__value.average-rating > span")
    score_list.append(score.text)
    abv = driver.find_element_by_css_selector("#main-content > div > div.spirit-show.center-column.js-carousel.vodka-content > div.primary-content > div.tabs > div > div > div.spirit-show__description-container > div.other-details-container > ul > div > li.detail.abv > div.value")
    abv_list.append(abv.text)
    des = driver.find_element_by_css_selector("#main-content > div > div.spirit-show.center-column.js-carousel.vodka-content > div.primary-content > div.tabs > div > div > div.spirit-show__description-container > div.other-details-container > ul > li.detail.whiskey-style > div.value")
    des_list.append(des.text)
    try :
        canvasTemp=driver.find_element_by_css_selector(".js-flavor-profile-chart")
        taste_list.append(canvasTemp.get_attribute('data-flavors'))
    except :
        taste_list.append("")
        print("오류")
    url = driver.current_url
    res = req.get(url)
    found = re.search(pattern,res.text)
    img_list.append(found.group(1))
    num_list.append(i+1)
    driver.back()
    time.sleep(2)
    
    
    
dic = {"순서" : num_list,"상품명" : name_list, "별점" : score_list, "도수" : abv_list, "설명" : des_list, "맛과향" : taste_list, "이미지" : img_list}
fin = pd.DataFrame(dic)

# %%
body = driver.find_element_by_css_selector("body")
    body.send_keys(Keys.PAGE_DOWN)
fin

# %%
#시헙용

# %%
from selenium import webdriver as wb
from selenium.webdriver.common.keys import Keys
import time
import requests as req
from bs4 import BeautifulSoup as bs
import re
import pandas as pd

# %%
driver = wb.Chrome()
time.sleep(2)
driver.get("https://distiller.com/search?page=3&sort=total_num_of_ratings&spirit_style_id=123")
time.sleep(2)

# %%
pattern = re.compile('url\((.*?)\)') 
name_list = [] #이름
score_list = [] #별점
abv_list = [] #도수
des_list = [] #설명
taste_list = [] #맛, 향
img_list = [] # 이미지
num_list = [] #순서
num = 0

driver = wb.Chrome()
time.sleep(2)
# driver.get("https://distiller.com/search?page=3&sort=total_num_of_ratings&spirit_style_id=123")
# time.sleep(2)



for j in range(1,75):
    driver.get('https://distiller.com/search?page='+str(j)+'&sort=total_num_of_ratings&spirit_style_id=123')
    time.sleep(2)
    for i in range(10) :
        try:
            btn = driver.find_elements_by_class_name("name")
            btn[i].click()
            time.sleep(2)
            name = driver.find_element_by_css_selector("span.secondary-headline.name")
            name_list.append(name.text)
            try:
                score = driver.find_element_by_css_selector("#main-content > div > div.spirit-show.center-column.js-carousel.vodka-content > div.primary-content > div.tabs > div > div > div.stats-container > div > div > div > div > div.rating-display__value.average-rating > span")
                score_list.append(score.text)
            except:
                score_list.append("none")
            abv = driver.find_element_by_css_selector("#main-content > div > div.spirit-show.center-column.js-carousel.vodka-content > div.primary-content > div.tabs > div > div > div.spirit-show__description-container > div.other-details-container > ul > div > li.detail.abv > div.value")
            abv_list.append(abv.text)
            des = driver.find_element_by_css_selector("#main-content > div > div.spirit-show.center-column.js-carousel.vodka-content > div.primary-content > div.tabs > div > div > div.spirit-show__description-container > div.other-details-container > ul > li.detail.whiskey-style > div.value")
            des_list.append(des.text)
            try :
                canvasTemp=driver.find_element_by_css_selector(".js-flavor-profile-chart")
                taste_list.append(canvasTemp.get_attribute('data-flavors'))
            except :
                taste_list.append("none")
                print("오류")
            url = driver.current_url
            res = req.get(url)
            found = re.search(pattern,res.text)
            img_list.append(found.group(1))
            num_list.append(num+1)
            num = num + 1
            driver.back()
            time.sleep(2)
        except:
            body = driver.find_element_by_css_selector("body")
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)#
            body.send_keys(Keys.ARROW_DOWN)
            print("다운")
        
    
dic = {"순서" : num_list,"상품명" : name_list, "별점" : score_list, "도수" : abv_list, "설명" : des_list, "맛과향" : taste_list, "이미지" : img_list}
fin = pd.DataFrame(dic)
# Out:
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_10264/3048418090.py:23: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   btn = driver.find_elements_by_class_name("name")
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_10264/3048418090.py:26: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   name = driver.find_element_by_css_selector("span.secondary-headline.name")
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_10264/3048418090.py:29: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   score = driver.find_element_by_css_selector("#main-content > div > div.spirit-show.center-column.js-carousel.vodka-content > div.primary-content > div.tabs > div > div > div.stats-container > div > div > div > div > div.rating-display__value.average-rating > span")
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_10264/3048418090.py:33: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   abv = driver.find_element_by_css_selector("#main-content > div > div.spirit-show.center-column.js-carousel.vodka-content > div.primary-content > div.tabs > div > div > div.spirit-show__description-container > div.other-details-container > ul > div > li.detail.abv > div.value")
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_10264/3048418090.py:35: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   des = driver.find_element_by_css_selector("#main-content > div > div.spirit-show.center-column.js-carousel.vodka-content > div.primary-content > div.tabs > div > div > div.spirit-show__description-container > div.other-details-container > ul > li.detail.whiskey-style > div.value")
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_10264/3048418090.py:38: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   canvasTemp=driver.find_element_by_css_selector(".js-flavor-profile-chart")
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_10264/3048418090.py:52: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   body = driver.find_element_by_css_selector("body")
# 다운
# 오류
# 다운
# 오류
# 오류
# 오류
# 오류
# 다운
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 다운
# 오류
# 오류
# 오류
# 오류
# 다운
# 오류
# 오류
# 오류
# 오류
# 오류
# 다운
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 다운
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 다운
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 다운
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 다운
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 다운
# 오류
# 오류
# 오류
# 오류
# 오류
# 다운
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 다운
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 다운
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 다운
# 오류
# 오류
# 오류
# 다운
# 오류
# 오류
# 오류
# 오류
# 다운
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 다운
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 다운
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 다운
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 다운
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 다운
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 다운
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 다운
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 다운
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 다운
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 다운
# 오류
# 오류
# 오류
# 다운
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 다운
# 오류
# 다운
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 다운
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 다운
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 다운
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 다운
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 다운
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 다운
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 다운
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 다운
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 다운
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 다운
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 다운
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 다운
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 다운
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 다운
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 다운
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 다운
# 오류
# 오류
# 다운
# 오류
# 오류
# 오류
# 오류
# 오류
# 다운
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 다운
# 오류
# 오류
# 오류
# 오류
# 다운
# 오류
# 오류
# 다운
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 다운
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 다운
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 다운
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 다운
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 다운
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 다운
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 다운
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 다운
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 다운
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 다운
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 다운
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 다운
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 다운
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 다운
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 다운
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 다운
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 다운
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 다운
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 다운
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 다운
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 다운
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 다운
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 다운
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 다운
# 오류
# 오류
# 오류
# 오류
# 오류
# 오류
# 다운
# 오류
# 오류
# 다운
# 오류
# 오류
# 오류
# 다운

# %%
fin
# Out:
#       순서                                상품명    별점    도수  \
# 0      1                       TITO'S VODKA   3.8  40.0
# 1      2                      ABSOLUT VODKA   3.1  40.0
# 2      3                   GREY GOOSE VODKA  3.78  40.0
# 3      4                    KETEL ONE VODKA   3.9  40.0
# 4      5                        REYKA VODKA  4.19  40.0
# ..   ...                                ...   ...   ...
# 657  658                    BLACKFISH VODKA  none  40.0
# 658  659                       AXBERG VODKA  none  40.0
# 659  660        44 NORTH MAGIC VALLEY WHEAT  none  40.0
# 660  661          TREATY OAK STARLITE VODKA  none  40.0
# 661  662  THE HARDWARE DISTILLERY CO. VODKA  none  40.0
#
#                                                     설명  \
# 0    DISTILLED FROM ANY AGRICULTURAL PRODUCT, MOST ...
# 1    DISTILLED FROM ANY AGRICULTURAL PRODUCT, MOST ...
# 2    DISTILLED FROM ANY AGRICULTURAL PRODUCT, MOST ...
# 3    DISTILLED FROM ANY AGRICULTURAL PRODUCT, MOST ...
# 4    DISTILLED FROM ANY AGRICULTURAL PRODUCT, MOST ...
# ..                                                 ...
# 657  DISTILLED FROM ANY AGRICULTURAL PRODUCT, MOST ...
# 658  DISTILLED FROM ANY AGRICULTURAL PRODUCT, MOST ...
# 659  DISTILLED FROM ANY AGRICULTURAL PRODUCT, MOST ...
# 660  DISTILLED FROM ANY AGRICULTURAL PRODUCT, MOST ...
# 661  DISTILLED FROM ANY AGRICULTURAL PRODUCT, MOST ...
#
#                                                    맛과향  \
# 0    {"grain":30,"earthy":15,"spicy":35,"herbal":10...
# 1    {"grain":75,"earthy":20,"spicy":15,"herbal":15...
# 2    {"grain":40,"earthy":30,"spicy":30,"herbal":15...
# 3    {"grain":80,"earthy":20,"spicy":35,"herbal":0,...
# 4    {"grain":70,"earthy":20,"spicy":45,"herbal":15...
# ..                                                 ...
# 657  {"grain":20,"earthy":30,"spicy":0,"herbal":0,"...
# 658                                               none
# 659                                               none
# 660                                               none
# 661  {"grain":45,"earthy":35,"spicy":0,"herbal":0,"...
#
#                                                    이미지
# 0    https://ip-distiller.imgix.net/images/spirits/...
# 1    https://ip-distiller.imgix.net/images/spirits/...
# 2    https://ip-distiller.imgix.net/images/spirits/...
# 3    https://ip-distiller.imgix.net/images/spirits/...
# 4    https://ip-distiller.imgix.net/images/spirits/...
# ..                                                 ...
# 657  https://ip-distiller.imgix.net/images/spirits/...
# 658  https://ip-distiller.imgix.net/images/spirits/...
# 659  https://ip-distiller.imgix.net/images/spirits/...
# 660  https://ip-distiller.imgix.net/images/spirits/...
# 661  https://ip-distiller.imgix.net/images/spirits/...
#
# [662 rows x 7 columns]

# %%
fin.to_csv("distiller-무향보드카.csv", encoding="utf-8-sig")

# %%
url =  'https://distiller.com/search?page='+str(2)+'&sort=total_num_of_ratings&spirit_style_id=123'
driver = wb.Chrome()
driver.get(url)

# %%
#와인앤키

# %%
driver = wb.Chrome()
driver.get("http://wine1865.co.kr/list/001")

# %%
driver = wb.Chrome()
driver.get("http://wine1865.co.kr/list/001")
btn = driver.find_elements_by_css_selector("li.bestChoiceList")
btn[6].click()

# %%
#container > div:nth-child(2) > ul > li:nth-child(1) > div > img
#container > div:nth-child(2) > ul > li:nth-child(2) > div > img
