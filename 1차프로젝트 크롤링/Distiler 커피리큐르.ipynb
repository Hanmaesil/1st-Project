# %%
from selenium import webdriver as wb
from selenium.webdriver.common.keys import Keys
import time
import random
import requests as req
from bs4 import BeautifulSoup as bs
import re
import pandas as pd

# %%
pattern = re.compile('url\((.*?)\)') 
name_list = [] #이름
score_list = [] #별점
abv_list = [] #도수
des_list = [] #설명
taste_list = [] #맛, 향
img_list = [] # 이미지
num_list = [] #순서
num = 0

driver = wb.Chrome()
driver.maximize_window()
time.sleep(random.uniform(2,4))

for j in range(1,11):
    driver.get('https://distiller.com/search?page='+str(j)+'&sort=total_num_of_ratings&spirit_style_id=137')
    time.sleep(random.uniform(2,4))
    for i in range(10) :
        try:
            btn = driver.find_elements_by_class_name("name")
            btn[i].click()
            time.sleep(random.uniform(2,4))
            name = driver.find_element_by_css_selector("span.secondary-headline.name")
            name_list.append(name.text)
            try:
                score = driver.find_element_by_css_selector('#main-content > div > div.spirit-show.center-column.js-carousel.liqueur-content > div.primary-content > div > div > div > div.stats-container > div > div > div > div > div.rating-display__value.average-rating > span')
                score_list.append(score.text)
            except:
                score_list.append("none")
            abv = driver.find_element_by_css_selector('#main-content > div > div.spirit-show.center-column.js-carousel.liqueur-content > div.primary-content > div > div > div > div.spirit-show__description-container > div.other-details-container > ul > div > li.detail.abv > div.value')
            abv_list.append(abv.text)
            try:
                des = driver.find_element_by_css_selector('#main-content > div > div.spirit-show.center-column.js-carousel.liqueur-content > div.primary-content > div > div > div > div.spirit-show__description-container > div.only-big > p')
                des_list.append(des.text)
                print("설명 입력")
            except:
                des_list.append("none")
                print("설명없음")
            try :
                canvasTemp=driver.find_element_by_css_selector(".js-flavor-profile-chart")
                taste_list.append(canvasTemp.get_attribute('data-flavors'))
            except :
                taste_list.append("none")
                print("오류")
            url = driver.current_url
            res = req.get(url)
            found = re.search(pattern,res.text)
            img_list.append(found.group(1))
            num_list.append(num+1)
            num = num + 1
            driver.back()
            time.sleep(random.uniform(2,4))
        except:
            body = driver.find_element_by_css_selector("body")
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)
            body.send_keys(Keys.ARROW_DOWN)#
            body.send_keys(Keys.ARROW_DOWN)
            print("다운")
        
    
dic = {"순서" : num_list,"상품명" : name_list, "별점" : score_list, "도수" : abv_list, "설명" : des_list, "맛과향" : taste_list, "이미지" : img_list}
fin = pd.DataFrame(dic)
fin
# Out:
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_2276/3056774849.py:20: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   btn = driver.find_elements_by_class_name("name")
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_2276/3056774849.py:23: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   name = driver.find_element_by_css_selector("span.secondary-headline.name")
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_2276/3056774849.py:26: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   score = driver.find_element_by_css_selector('#main-content > div > div.spirit-show.center-column.js-carousel.liqueur-content > div.primary-content > div > div > div > div.stats-container > div > div > div > div > div.rating-display__value.average-rating > span')
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_2276/3056774849.py:30: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   abv = driver.find_element_by_css_selector('#main-content > div > div.spirit-show.center-column.js-carousel.liqueur-content > div.primary-content > div > div > div > div.spirit-show__description-container > div.other-details-container > ul > div > li.detail.abv > div.value')
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_2276/3056774849.py:33: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   des = driver.find_element_by_css_selector('#main-content > div > div.spirit-show.center-column.js-carousel.liqueur-content > div.primary-content > div > div > div > div.spirit-show__description-container > div.only-big > p')
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_2276/3056774849.py:40: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   canvasTemp=driver.find_element_by_css_selector(".js-flavor-profile-chart")
# 설명 입력
# 설명 입력
# 설명 입력
# 설명없음
# 오류
# C:\Users\smhrd\AppData\Local\Temp/ipykernel_2276/3056774849.py:54: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   body = driver.find_element_by_css_selector("body")
# 다운
# 설명없음
# 오류
# 설명 입력
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명 입력
# 오류
# 설명 입력
# 오류
# 설명 입력
# 다운
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 다운
# 설명없음
# 오류
# 설명없음
# 오류
# 설명 입력
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 다운
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 다운
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명 입력
# 다운
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 다운
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명 입력
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명 입력
# 오류
# 설명없음
# 오류
# 다운
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명 입력
# 오류
# 다운
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명 입력
# 설명 입력
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명없음
# 오류
# 설명 입력
# 다운
# 설명없음
# 오류
# 다운
# 다운
# 다운
# 다운
#     순서                                상품명    별점    도수  \
# 0    1                             KAHLÚA  3.19  20.0
# 1    2                     PATRÓN XO CAFE  3.37  35.0
# 2    3  MR BLACK COLD BREW COFFEE LIQUEUR  4.47  25.0
# 3    4                         SHERIDAN’S  3.72  15.5
# 4    5                GRIND ESPRESSO SHOT   4.3  30.0
# ..  ..                                ...   ...   ...
# 81  82        DOLCE NERO ESPRESSO LIQUEUR  none  20.0
# 82  83             FIRELIT COFFEE LIQUEUR  none  30.0
# 83  84      CH DARK MATTER COFFEE LIQUEUR  none  29.0
# 84  85            LYON COFFEE RUM LIQUEUR  none  36.0
# 85  86                 SALT CITY ESPRESSO  none  30.0
#
#                                                    설명  \
# 0   Kahlúa is a coffee flavored liqueur produced i...
# 1   Patrón XO Cafe is a coffee liqueur made by usi...
# 2   Mr Black Cold Brew Coffee Liqueur is made at a...
# 3                                                none
# 4                                                none
# ..                                                ...
# 81                                               none
# 82                                               none
# 83                                               none
# 84  Maryland’s Lyon Distilling Co. has added a var...
# 85                                               none
#
#                                                   맛과향  \
# 0   {"sweet":90,"rich":70,"spicy":35,"herbal":0,"f...
# 1   {"sweet":50,"rich":45,"spicy":0,"herbal":0,"fr...
# 2   {"sweet":50,"rich":80,"spicy":0,"herbal":0,"fr...
# 3                                                none
# 4                                                none
# ..                                                ...
# 81                                               none
# 82                                               none
# 83                                               none
# 84  {"sweet":55,"rich":70,"spicy":35,"herbal":10,"...
# 85                                               none
#
#                                                   이미지
# 0   https://ip-distiller.imgix.net/images/spirits/...
# 1   https://ip-distiller.imgix.net/images/spirits/...
# 2   https://ip-distiller.imgix.net/images/spirits/...
# 3   https://ip-distiller.imgix.net/images/spirits/...
# 4   https://ip-distiller.imgix.net/images/spirits/...
# ..                                                ...
# 81  https://ip-distiller.imgix.net/images/spirits/...
# 82  https://ip-distiller.imgix.net/images/spirits/...
# 83  https://ip-distiller.imgix.net/images/spirits/...
# 84  https://ip-distiller.imgix.net/images/spirits/...
# 85  https://ip-distiller.imgix.net/images/spirits/...
#
# [86 rows x 7 columns]

# %%
fin.to_csv("distiller-커피리큐르.csv", encoding="utf-8-sig")
